# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import logging
from tqdm.notebook import tqdm_notebook
from concurrent.futures import ThreadPoolExecutor
import random
import yaml
import numpy as np
from fuzzywuzzy import fuzz

# %%
# Logging setup
logging.basicConfig(level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s")

# Load configuration
with open("config.yaml", "r") as file:
    config = yaml.safe_load(file)

# %%
# Randomized sleep to mimic human behavior
def random_sleep():
    time.sleep(random.uniform(*config["sleep_range"]))

# %%
# Fetch URL with retry logic and exponential backoff
def fetch_with_retry(url, max_retries=config["retries"]):
    for i in range(max_retries):
        try:
            response = requests.get(url, headers=config["headers"], timeout=10)
            if response.status_code == 200:
                return response
            elif response.status_code == 404:
                logging.warning(f"404 Not Found: {url}")
                return None
        except requests.RequestException as e:
            logging.warning(f"Retrying ({i + 1}/{max_retries}) for {url}: {e}")
        time.sleep(random.uniform(2, 5))  # Randomized delay
    logging.error(f"Failed to fetch {url} after {max_retries} retries")
    return None

# %%
### STEP 1: SCRAPE FIGHTER LISTS ###

# UFC Stats: Generate fighter list URLs
def generate_ufcstats_urls():
    base_url = "http://ufcstats.com/statistics/fighters?char={}&page={}"
    urls = []
    for char in "abcdefghijklmnopqrstuvwxyz":
        page = 1
        while True:
            url = base_url.format(char, page)
            response = fetch_with_retry(url)
            if response and "No fighter" not in response.text:
                urls.append(url)
                page += 1
            else:
                break
    return urls

# Find UFC Stats URL dynamically
def find_ufcstats_url(fighter_name):
    search_url = f"http://ufcstats.com/statistics/fighters?char={fighter_name[0].lower()}"
    response = fetch_with_retry(search_url)
    if not response:
        return None

    soup = BeautifulSoup(response.text, "html.parser")
    fighter_links = soup.find_all("a", class_="b-link b-link_style_black")
    for link in fighter_links:
        if fighter_name.lower() in link.text.strip().lower():
            return link["href"]
    logging.warning(f"Could not find UFC Stats URL for {fighter_name}")
    return None

# Scrape UFC Stats details
def scrape_ufcstats_details(url):
    response = fetch_with_retry(url)
    if not response or response.status_code == 404:
        return {}

    soup = BeautifulSoup(response.text, "html.parser")
    details = {}

    try:
        stats_table = soup.find("table", class_="b-list__info-box")
        if not stats_table:
            return {}

        rows = stats_table.find_all("tr")
        for row in rows:
            cells = row.find_all("td")
            if len(cells) == 2:
                label = cells[0].text.strip()
                value = cells[1].text.strip()
                if label == "Height:":
                    details["HEIGHT"] = value
                elif label == "Weight:":
                    details["WEIGHT"] = value
                elif label == "Reach:":
                    details["REACH"] = value
                elif label == "Stance:":
                    details["STANCE"] = value
                elif label == "DOB:":
                    details["DOB"] = value
    except Exception as e:
        logging.error(f"Error parsing UFC Stats: {url} - {e}")
    return details

# %%
# Scrape UFC Official details
def scrape_ufc_details(fighter_name):
    base_url = f"https://www.ufc.com/athlete/{fighter_name.replace(' ', '-').lower()}"
    response = fetch_with_retry(base_url)
    if not response or response.status_code == 404:
        return {}

    soup = BeautifulSoup(response.text, "html.parser")
    details = {}
    try:
        bio_sections = soup.find_all("div", class_="c-bio__text")
        for section in bio_sections:
            label = section.find_previous("div", class_="c-bio__label").text.strip()
            value = section.text.strip()
            if label == "Height":
                details["HEIGHT"] = value
            elif label == "Weight":
                details["WEIGHT"] = value
            elif label == "Reach":
                details["REACH"] = value
    except Exception as e:
        logging.warning(f"Error parsing UFC Official page: {base_url} - {e}")
    return details

# %%
# MMA Decisions: Generate fighter list URLs
def generate_mmadecisions_urls():
    base_url = "https://mmadecisions.com/decisions-by-fighter/{}"
    return [base_url.format(char) for char in "abcdefghijklmnopqrstuvwxyz"]# Scrape MMA Decisions details
def scrape_mmadecisions_details(fighter_name):
    base_url = f"https://mmadecisions.com/search.php?search_query={fighter_name.replace(' ', '+')}"
    response = fetch_with_retry(base_url)
    if not response:
        return {}

    soup = BeautifulSoup(response.text, "html.parser")
    details = {}
    return details

# %%
# MMA Decisions: Scrape fighter names and URLs
def scrape_mmadecisions_fighter_list(url):
    response = fetch_with_retry(url)
    if not response:
        return []

    soup = BeautifulSoup(response.text, "html.parser")
    rows = soup.find_all("a", href=True)
    fighters = []
    for row in rows:
        if "/fighter/" in row["href"]:
            name = row.text.strip()
            fighter_url = f"https://mmadecisions.com{row['href']}"
            fighters.append({"FIGHTER": name, "MMADECISIONS_URL": fighter_url})
    return fighters

# %%
# Combine all fighter lists
def scrape_all_fighter_lists():
    logging.info("Scraping fighter lists from UFC Stats, UFC Official, and MMA Decisions...")
    fighter_list = []

    # UFC Stats
    ufcstats_urls = generate_ufcstats_urls()
    for url in ufcstats_urls:
        fighter_list.extend(scrape_ufcstats_fighter_list(url))

    # UFC Official
    fighter_list.extend(scrape_ufc_fighter_list())

    # MMA Decisions
    mmadecisions_urls = generate_mmadecisions_urls()
    for url in mmadecisions_urls:
        fighter_list.extend(scrape_mmadecisions_fighter_list(url))

    # Deduplicate by fighter name
    fighter_df = pd.DataFrame(fighter_list).drop_duplicates(subset=["FIGHTER"]).reset_index(drop=True)
    return fighter_df

# %%
### STEP 2: SCRAPE FIGHTER DETAILS ###

# UFC Stats: Scrape fighter details
def scrape_ufcstats_details(url):
    response = fetch_with_retry(url)
    if not response or response.status_code == 404:
        return {}

    soup = BeautifulSoup(response.text, "html.parser")
    details = {}
    try:
        stats_table = soup.find("table", class_="b-list__info-box")
        if not stats_table:
            return {}

        rows = stats_table.find_all("tr")
        for row in rows:
            cells = row.find_all("td")
            if len(cells) == 2:
                label = cells[0].text.strip()
                value = cells[1].text.strip()
                if label == "Height:":
                    details["HEIGHT"] = value
                elif label == "Weight:":
                    details["WEIGHT"] = value
                elif label == "Reach:":
                    details["REACH"] = value
                elif label == "Stance:":
                    details["STANCE"] = value
                elif label == "DOB:":
                    details["DOB"] = value
    except Exception as e:
        logging.error(f"Error parsing UFC Stats: {url} - {e}")
    return details

# %%
# UFC Official: Scrape fighter details
def scrape_ufc_details(fighter_name):
    base_url = f"https://www.ufc.com/athlete/{fighter_name.replace(' ', '-').lower()}"
    response = fetch_with_retry(base_url)
    if not response or response.status_code == 404:
        return {}

    soup = BeautifulSoup(response.text, "html.parser")
    details = {}
    try:
        bio_sections = soup.find_all("div", class_="c-bio__text")
        for section in bio_sections:
            label = section.find_previous("div", class_="c-bio__label").text.strip()
            value = section.text.strip()
            if label == "Height":
                details["HEIGHT"] = value
            elif label == "Weight":
                details["WEIGHT"] = value
            elif label == "Reach":
                details["REACH"] = value
    except Exception as e:
        logging.warning(f"Error parsing UFC Official page: {base_url} - {e}")
    return details

# %%
# MMA Decisions: Scrape fighter details
def scrape_mmadecisions_details(fighter_name):
    base_url = f"https://mmadecisions.com/search.php?search_query={fighter_name.replace(' ', '+')}"
    response = fetch_with_retry(base_url)
    if not response:
        return {}

    soup = BeautifulSoup(response.text, "html.parser")
    details = {}
    return details

# %%
# Aggregate fighter details from all sources
def aggregate_fighter_details(fighter_name):
    details = {"FIGHTER": fighter_name}

    # Step 1: Try UFC Stats
    ufcstats_url = find_ufcstats_url(fighter_name)
    if ufcstats_url:
        details.update(scrape_ufcstats_details(ufcstats_url))
        details["UFC_URL"] = ufcstats_url

    # Step 2: Try UFC Official if missing data
    if any(pd.isna(details.get(key)) for key in ["HEIGHT", "WEIGHT", "REACH"]):
        ufc_official_details = scrape_ufc_details(fighter_name)
        details.update({k: ufc_official_details.get(k, v) for k, v in details.items() if pd.isna(v)})

    # Step 3: Try MMA Decisions if still missing data
    if any(pd.isna(details.get(key)) for key in ["HEIGHT", "WEIGHT", "REACH"]):
        mma_details = scrape_mmadecisions_details(fighter_name)
        details.update({k: mma_details.get(k, v) for k, v in details.items() if pd.isna(v)})

    return details

# %%
# Scrape fighter details in parallel
def process_fighters_parallel(fighter_names):
    with ThreadPoolExecutor(max_workers=10) as executor:
        results = list(executor.map(aggregate_fighter_details, fighter_names))
    return results

# %%
### MAIN EXECUTION ###
if __name__ == "__main__":
    # Load fighter names from CSV
    fighter_names = pd.read_csv("data/fighter_names.csv")["Name"].tolist()

    logging.info(f"Starting scraping for {len(fighter_names)} fighters...")
    fighter_details = process_fighters_parallel(fighter_names)
    fighter_details_df = pd.DataFrame(fighter_details)
    fighter_details_df.to_csv("data/fighter_details.csv", index=False)
    logging.info("Fighter details saved to data/fighter_details.csv.")
# Out:
# 2025-01-27 15:27:59,005 - INFO - Starting scraping for 347 fighters...
# 2025-01-27 15:27:59,824 - WARNING - Could not find UFC Stats URL for Sam Adkins
# 2025-01-27 15:27:59,894 - WARNING - Could not find UFC Stats URL for Danny Abbadi
# 2025-01-27 15:27:59,921 - WARNING - Could not find UFC Stats URL for Scott Adams
# 2025-01-27 15:28:00,041 - WARNING - Could not find UFC Stats URL for Nick Agallar
# 2025-01-27 15:28:00,076 - WARNING - Could not find UFC Stats URL for David Abbott
# 2025-01-27 15:28:00,105 - WARNING - Could not find UFC Stats URL for Ricardo Abreu
# 2025-01-27 15:28:00,174 - WARNING - Could not find UFC Stats URL for Razak Al-Hassan
# 2025-01-27 15:28:00,178 - WARNING - Could not find UFC Stats URL for Marcelo Aguiar
# 2025-01-27 15:28:00,221 - WARNING - Could not find UFC Stats URL for Papy Abedi
# 2025-01-27 15:28:00,245 - WARNING - Could not find UFC Stats URL for Wes Albritton
# 2025-01-27 15:28:11,870 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Sam+Adkins after 3 retries
# 2025-01-27 15:28:12,418 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Ricardo+Abreu after 3 retries
# 2025-01-27 15:28:12,508 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Razak+Al-Hassan after 3 retries
# 2025-01-27 15:28:12,518 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Nick+Agallar after 3 retries
# 2025-01-27 15:28:12,651 - WARNING - Could not find UFC Stats URL for Alfonso Alcarez
# 2025-01-27 15:28:12,947 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Wes+Albritton after 3 retries
# 2025-01-27 15:28:13,072 - WARNING - Could not find UFC Stats URL for Royce Alger
# 2025-01-27 15:28:13,277 - WARNING - Could not find UFC Stats URL for Gilbert Aldana
# 2025-01-27 15:28:13,293 - WARNING - Could not find UFC Stats URL for George Allen
# 2025-01-27 15:28:13,293 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Marcelo+Aguiar after 3 retries
# 2025-01-27 15:28:13,806 - WARNING - Could not find UFC Stats URL for Ericka Almeida
# 2025-01-27 15:28:13,862 - WARNING - Could not find UFC Stats URL for Sean Alvarez
# 2025-01-27 15:28:14,674 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Scott+Adams after 3 retries
# 2025-01-27 15:28:15,002 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=David+Abbott after 3 retries
# 2025-01-27 15:28:15,016 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Danny+Abbadi after 3 retries
# 2025-01-27 15:28:15,223 - WARNING - Could not find UFC Stats URL for Amilcar Alves
# 2025-01-27 15:28:15,567 - WARNING - Could not find UFC Stats URL for Andy Anderson
# 2025-01-27 15:28:15,583 - WARNING - Could not find UFC Stats URL for Matt Andersen
# 2025-01-27 15:28:16,035 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Papy+Abedi after 3 retries
# 2025-01-27 15:28:16,843 - WARNING - Could not find UFC Stats URL for Lowell Anderson
# 2025-01-27 15:28:25,045 - ERROR - Failed to fetch https://www.ufc.com/athlete/george-allen after 3 retries
# 2025-01-27 15:28:25,318 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Matt+Andersen after 3 retries
# 2025-01-27 15:28:26,213 - WARNING - Could not find UFC Stats URL for Alex Andrade
# 2025-01-27 15:28:27,190 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Gilbert+Aldana after 3 retries
# 2025-01-27 15:28:27,284 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Royce+Alger after 3 retries
# 2025-01-27 15:28:27,909 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Alfonso+Alcarez after 3 retries
# 2025-01-27 15:28:27,976 - WARNING - Could not find UFC Stats URL for Jermaine Andre
# 2025-01-27 15:28:28,108 - WARNING - Could not find UFC Stats URL for Reese Andy
# 2025-01-27 15:28:28,758 - WARNING - Could not find UFC Stats URL for Yoji Anjo
# 2025-01-27 15:28:29,055 - ERROR - Failed to fetch https://www.ufc.com/athlete/amilcar-alves after 3 retries
# 2025-01-27 15:28:29,488 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Sean+Alvarez after 3 retries
# 2025-01-27 15:28:30,083 - WARNING - Could not find UFC Stats URL for Azunna Anyanwu
# 2025-01-27 15:28:30,182 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Ericka+Almeida after 3 retries
# 2025-01-27 15:28:30,732 - WARNING - Could not find UFC Stats URL for Romie Aram
# 2025-01-27 15:28:31,549 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Andy+Anderson after 3 retries
# 2025-01-27 15:28:31,584 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Lowell+Anderson after 3 retries
# 2025-01-27 15:28:32,383 - WARNING - Could not find UFC Stats URL for Cesar Arzamendia
# 2025-01-27 15:28:32,428 - WARNING - Could not find UFC Stats URL for Khusein Askhabov
# 2025-01-27 15:28:37,365 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=George+Allen after 3 retries
# 2025-01-27 15:28:38,418 - WARNING - Could not find UFC Stats URL for Ibo Aslan
# 2025-01-27 15:28:40,752 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Alex+Andrade after 3 retries
# 2025-01-27 15:28:42,339 - WARNING - Could not find UFC Stats URL for Pat Audinwood
# 2025-01-27 15:28:42,658 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Reese+Andy after 3 retries
# 2025-01-27 15:28:43,010 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Jermaine+Andre after 3 retries
# 2025-01-27 15:28:43,206 - WARNING - Could not find UFC Stats URL for Chris Avila
# 2025-01-27 15:28:43,550 - WARNING - Could not find UFC Stats URL for Niklas Backstrom
# 2025-01-27 15:28:43,752 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Yoji+Anjo after 3 retries
# 2025-01-27 15:28:44,283 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Amilcar+Alves after 3 retries
# 2025-01-27 15:28:44,301 - WARNING - Could not find UFC Stats URL for Izabela Badurek
# 2025-01-27 15:28:45,041 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Romie+Aram after 3 retries
# 2025-01-27 15:28:45,191 - WARNING - Could not find UFC Stats URL for Mehdi Baghdad
# 2025-01-27 15:28:45,618 - WARNING - Could not find UFC Stats URL for Scott Baker
# 2025-01-27 15:28:45,951 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Khusein+Askhabov after 3 retries
# 2025-01-27 15:28:46,068 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Cesar+Arzamendia after 3 retries
# 2025-01-27 15:28:46,521 - WARNING - Could not find UFC Stats URL for Marcin Bandel
# 2025-01-27 15:28:46,574 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Azunna+Anyanwu after 3 retries
# 2025-01-27 15:28:46,649 - WARNING - Could not find UFC Stats URL for David Baron
# 2025-01-27 15:28:47,137 - WARNING - Could not find UFC Stats URL for Dan Barrera
# 2025-01-27 15:28:50,408 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Ibo+Aslan after 3 retries
# 2025-01-27 15:28:50,958 - WARNING - Could not find UFC Stats URL for Carlos Barreto
# 2025-01-27 15:28:54,828 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Niklas+Backstrom after 3 retries
# 2025-01-27 15:28:55,409 - WARNING - Could not find UFC Stats URL for Alexandre Barros
# 2025-01-27 15:28:55,601 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Pat+Audinwood after 3 retries
# 2025-01-27 15:28:56,160 - WARNING - Could not find UFC Stats URL for Dean Barry
# 2025-01-27 15:28:58,355 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Chris+Avila after 3 retries
# 2025-01-27 15:28:58,670 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Marcin+Bandel after 3 retries
# 2025-01-27 15:28:58,899 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Dan+Barrera after 3 retries
# 2025-01-27 15:28:59,137 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Mehdi+Baghdad after 3 retries
# 2025-01-27 15:28:59,345 - WARNING - Could not find UFC Stats URL for Shayna Baszler
# 2025-01-27 15:28:59,486 - WARNING - Could not find UFC Stats URL for Stephen Bass
# 2025-01-27 15:28:59,657 - WARNING - Could not find UFC Stats URL for Michel Batista
# 2025-01-27 15:28:59,785 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Scott+Baker after 3 retries
# 2025-01-27 15:28:59,954 - WARNING - Could not find UFC Stats URL for Dave Beneteau
# 2025-01-27 15:29:00,450 - WARNING - Could not find UFC Stats URL for Steve Berger
# 2025-01-27 15:29:01,279 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Izabela+Badurek after 3 retries
# 2025-01-27 15:29:01,831 - WARNING - Could not find UFC Stats URL for Keith Berish
# 2025-01-27 15:29:03,403 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=David+Baron after 3 retries
# 2025-01-27 15:29:03,971 - WARNING - Could not find UFC Stats URL for Dave Berry
# 2025-01-27 15:29:05,507 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Carlos+Barreto after 3 retries
# 2025-01-27 15:29:06,048 - WARNING - Could not find UFC Stats URL for Dieusel Berto
# 2025-01-27 15:29:07,853 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Alexandre+Barros after 3 retries
# 2025-01-27 15:29:08,400 - WARNING - Could not find UFC Stats URL for Allen Berube
# 2025-01-27 15:29:09,769 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Dean+Barry after 3 retries
# 2025-01-27 15:29:10,316 - WARNING - Could not find UFC Stats URL for Scott Bessac
# 2025-01-27 15:29:11,676 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Stephen+Bass after 3 retries
# 2025-01-27 15:29:12,425 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Dave+Beneteau after 3 retries
# 2025-01-27 15:29:12,483 - WARNING - Could not find UFC Stats URL for Amaury Bitetti
# 2025-01-27 15:29:13,024 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Shayna+Baszler after 3 retries
# 2025-01-27 15:29:13,862 - WARNING - Could not find UFC Stats URL for Tom Blackledge
# 2025-01-27 15:29:14,022 - WARNING - Could not find UFC Stats URL for Jason Black
# 2025-01-27 15:29:15,998 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Steve+Berger after 3 retries
# 2025-01-27 15:29:16,699 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Michel+Batista after 3 retries
# 2025-01-27 15:29:17,120 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Keith+Berish after 3 retries
# 2025-01-27 15:29:17,235 - WARNING - Could not find UFC Stats URL for Byron Bloodworth
# 2025-01-27 15:29:17,248 - WARNING - Could not find UFC Stats URL for Dan Bobish
# 2025-01-27 15:29:17,683 - WARNING - Could not find UFC Stats URL for Jerry Bohlander
# 2025-01-27 15:29:18,725 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Dave+Berry after 3 retries
# 2025-01-27 15:29:19,289 - WARNING - Could not find UFC Stats URL for Jesse Bongfeldt
# 2025-01-27 15:29:23,006 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Dieusel+Berto after 3 retries
# 2025-01-27 15:29:23,296 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Allen+Berube after 3 retries
# 2025-01-27 15:29:23,352 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Scott+Bessac after 3 retries
# 2025-01-27 15:29:23,576 - WARNING - Could not find UFC Stats URL for Marcus Bossett
# 2025-01-27 15:29:23,852 - WARNING - Could not find UFC Stats URL for Tai Bowden
# 2025-01-27 15:29:23,901 - WARNING - Could not find UFC Stats URL for Melton Bowen
# 2025-01-27 15:29:28,123 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Amaury+Bitetti after 3 retries
# 2025-01-27 15:29:28,940 - WARNING - Could not find UFC Stats URL for Paul Bradley
# 2025-01-27 15:29:29,430 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Tom+Blackledge after 3 retries
# 2025-01-27 15:29:29,777 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Jason+Black after 3 retries
# 2025-01-27 15:29:30,165 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Dan+Bobish after 3 retries
# 2025-01-27 15:29:30,221 - WARNING - Could not find UFC Stats URL for Ebenezer Fontes Braga
# 2025-01-27 15:29:30,482 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Byron+Bloodworth after 3 retries
# 2025-01-27 15:29:30,528 - WARNING - Could not find UFC Stats URL for Joe Brammer
# 2025-01-27 15:29:30,722 - WARNING - Could not find UFC Stats URL for Chris Brennan
# 2025-01-27 15:29:30,984 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Jerry+Bohlander after 3 retries
# 2025-01-27 15:29:31,064 - WARNING - Could not find UFC Stats URL for Aaron Brink
# 2025-01-27 15:29:31,538 - WARNING - Could not find UFC Stats URL for Todd Brown
# 2025-01-27 15:29:32,831 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Jesse+Bongfeldt after 3 retries
# 2025-01-27 15:29:33,629 - WARNING - Could not find UFC Stats URL for Humberto Brown Morrison
# 2025-01-27 15:29:36,125 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Melton+Bowen after 3 retries
# 2025-01-27 15:29:36,672 - WARNING - Could not find UFC Stats URL for Junie Browning
# 2025-01-27 15:29:38,446 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Tai+Bowden after 3 retries
# 2025-01-27 15:29:38,651 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Marcus+Bossett after 3 retries
# 2025-01-27 15:29:38,979 - WARNING - Could not find UFC Stats URL for Jules Bruchez
# 2025-01-27 15:29:39,201 - WARNING - Could not find UFC Stats URL for Steve Bruno
# 2025-01-27 15:29:43,248 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Chris+Brennan after 3 retries
# 2025-01-27 15:29:43,810 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Joe+Brammer after 3 retries
# 2025-01-27 15:29:44,057 - WARNING - Could not find UFC Stats URL for Fernando Bruno
# 2025-01-27 15:29:44,363 - WARNING - Could not find UFC Stats URL for Josh Bryant
# 2025-01-27 15:29:44,703 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Todd+Brown after 3 retries
# 2025-01-27 15:29:45,280 - WARNING - Could not find UFC Stats URL for Mikey Burnett
# 2025-01-27 15:29:45,726 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Ebenezer+Fontes+Braga after 3 retries
# 2025-01-27 15:29:46,310 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Aaron+Brink after 3 retries
# 2025-01-27 15:29:46,887 - WARNING - Could not find UFC Stats URL for Bubba Bush
# 2025-01-27 15:29:46,918 - WARNING - Could not find UFC Stats URL for Nah-Shon Burrell
# 2025-01-27 15:29:47,855 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Paul+Bradley after 3 retries
# 2025-01-27 15:29:48,449 - WARNING - Could not find UFC Stats URL for Murilo Bustamante
# 2025-01-27 15:29:52,055 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Steve+Bruno after 3 retries
# 2025-01-27 15:29:53,192 - WARNING - Could not find UFC Stats URL for Todd Butler
# 2025-01-27 15:29:53,477 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Junie+Browning after 3 retries
# 2025-01-27 15:29:53,647 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Humberto+Brown+Morrison after 3 retries
# 2025-01-27 15:29:54,072 - WARNING - Could not find UFC Stats URL for Steve Byrnes
# 2025-01-27 15:29:54,220 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Jules+Bruchez after 3 retries
# 2025-01-27 15:29:54,544 - WARNING - Could not find UFC Stats URL for John Campetella
# 2025-01-27 15:29:55,023 - WARNING - Could not find UFC Stats URL for Wagner Campos
# 2025-01-27 15:29:59,381 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Nah-Shon+Burrell after 3 retries
# 2025-01-27 15:29:59,947 - WARNING - Could not find UFC Stats URL for Asbel Cancio
# 2025-01-27 15:30:00,514 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Murilo+Bustamante after 3 retries
# 2025-01-27 15:30:00,524 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Fernando+Bruno after 3 retries
# 2025-01-27 15:30:00,859 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Mikey+Burnett after 3 retries
# 2025-01-27 15:30:01,255 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Josh+Bryant after 3 retries
# 2025-01-27 15:30:01,357 - WARNING - Could not find UFC Stats URL for Rafael Carino
# 2025-01-27 15:30:01,640 - WARNING - Could not find UFC Stats URL for Cain Carrizosa
# 2025-01-27 15:30:02,071 - WARNING - Could not find UFC Stats URL for Shonie Carter
# 2025-01-27 15:30:02,352 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Bubba+Bush after 3 retries
# 2025-01-27 15:30:02,740 - WARNING - Could not find UFC Stats URL for Frank Caracci
# 2025-01-27 15:30:03,180 - WARNING - Could not find UFC Stats URL for Dwayne Cason
# 2025-01-27 15:30:06,863 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Steve+Byrnes after 3 retries
# 2025-01-27 15:30:07,479 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Todd+Butler after 3 retries
# 2025-01-27 15:30:07,710 - WARNING - Could not find UFC Stats URL for Gil Castillo
# 2025-01-27 15:30:07,885 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=John+Campetella after 3 retries
# 2025-01-27 15:30:08,319 - WARNING - Could not find UFC Stats URL for Luke Caudillo
# 2025-01-27 15:30:08,573 - WARNING - Could not find UFC Stats URL for Adam Cella
# 2025-01-27 15:30:08,881 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Wagner+Campos after 3 retries
# 2025-01-27 15:30:09,479 - WARNING - Could not find UFC Stats URL for Ansar Chalangov
# 2025-01-27 15:30:13,785 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Cain+Carrizosa after 3 retries
# 2025-01-27 15:30:14,332 - WARNING - Could not find UFC Stats URL for Donnie Chappell
# 2025-01-27 15:30:15,626 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Asbel+Cancio after 3 retries
# 2025-01-27 15:30:16,244 - WARNING - Could not find UFC Stats URL for Joe Charles
# 2025-01-27 15:30:18,065 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Shonie+Carter after 3 retries
# 2025-01-27 15:30:18,904 - WARNING - Could not find UFC Stats URL for Albert Cheng
# 2025-01-27 15:30:19,288 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Frank+Caracci after 3 retries
# 2025-01-27 15:30:19,779 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Rafael+Carino after 3 retries
# 2025-01-27 15:30:19,861 - WARNING - Could not find UFC Stats URL for Sako Chivitchian
# 2025-01-27 15:30:20,341 - WARNING - Could not find UFC Stats URL for Will Chope
# 2025-01-27 15:30:21,491 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Dwayne+Cason after 3 retries
# 2025-01-27 15:30:21,520 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Gil+Castillo after 3 retries
# 2025-01-27 15:30:22,261 - WARNING - Could not find UFC Stats URL for Anthony Christodoulou
# 2025-01-27 15:30:22,298 - WARNING - Could not find UFC Stats URL for Dan Christison
# 2025-01-27 15:30:22,468 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Ansar+Chalangov after 3 retries
# 2025-01-27 15:30:23,257 - WARNING - Could not find UFC Stats URL for Mike Ciesnolevicz
# 2025-01-27 15:30:23,350 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Luke+Caudillo after 3 retries
# 2025-01-27 15:30:23,750 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Adam+Cella after 3 retries
# 2025-01-27 15:30:23,893 - WARNING - Could not find UFC Stats URL for Laverne Clark
# 2025-01-27 15:30:24,299 - WARNING - Could not find UFC Stats URL for Logan Clark
# 2025-01-27 15:30:27,087 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Donnie+Chappell after 3 retries
# 2025-01-27 15:30:27,631 - WARNING - Could not find UFC Stats URL for Josh Clopton
# 2025-01-27 15:30:33,715 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Joe+Charles after 3 retries
# 2025-01-27 15:30:34,596 - WARNING - Could not find UFC Stats URL for Brian Cobb
# 2025-01-27 15:30:34,626 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Albert+Cheng after 3 retries
# 2025-01-27 15:30:35,079 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Will+Chope after 3 retries
# 2025-01-27 15:30:35,457 - WARNING - Could not find UFC Stats URL for John Cofer
# 2025-01-27 15:30:35,649 - WARNING - Could not find UFC Stats URL for Christian Colombo
# 2025-01-27 15:30:36,090 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Sako+Chivitchian after 3 retries
# 2025-01-27 15:30:36,145 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Dan+Christison after 3 retries
# 2025-01-27 15:30:36,637 - WARNING - Could not find UFC Stats URL for Wes Combs
# 2025-01-27 15:30:36,702 - WARNING - Could not find UFC Stats URL for Chris Condo
# 2025-01-27 15:30:36,758 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Mike+Ciesnolevicz after 3 retries
# 2025-01-27 15:30:37,322 - WARNING - Could not find UFC Stats URL for Bob Cook
# 2025-01-27 15:30:37,366 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Anthony+Christodoulou after 3 retries
# 2025-01-27 15:30:38,155 - WARNING - Could not find UFC Stats URL for Kit Cope
# 2025-01-27 15:30:38,869 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Logan+Clark after 3 retries
# 2025-01-27 15:30:39,444 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Laverne+Clark after 3 retries
# 2025-01-27 15:30:39,640 - WARNING - Could not find UFC Stats URL for Josh Copeland
# 2025-01-27 15:30:41,172 - WARNING - Could not find UFC Stats URL for Wesley Correira
# 2025-01-27 15:30:42,831 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Josh+Clopton after 3 retries
# 2025-01-27 15:30:43,384 - WARNING - Could not find UFC Stats URL for JC Cottrell
# 2025-01-27 15:30:49,020 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Chris+Condo after 3 retries
# 2025-01-27 15:30:49,105 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Bob+Cook after 3 retries
# 2025-01-27 15:30:49,661 - WARNING - Could not find UFC Stats URL for Dan Cramer
# 2025-01-27 15:30:49,752 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Wes+Combs after 3 retries
# 2025-01-27 15:30:49,991 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=John+Cofer after 3 retries
# 2025-01-27 15:30:50,392 - WARNING - Could not find UFC Stats URL for Alberto Crane
# 2025-01-27 15:30:50,403 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Brian+Cobb after 3 retries
# 2025-01-27 15:30:50,587 - WARNING - Could not find UFC Stats URL for Jeff Cox
# 2025-01-27 15:30:51,167 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Kit+Cope after 3 retries
# 2025-01-27 15:30:51,767 - WARNING - Could not find UFC Stats URL for Marcio Cruz
# 2025-01-27 15:30:52,017 - WARNING - Could not find UFC Stats URL for Richard Crunkilton
# 2025-01-27 15:30:52,134 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Christian+Colombo after 3 retries
# 2025-01-27 15:30:52,272 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Josh+Copeland after 3 retries
# 2025-01-27 15:30:52,411 - WARNING - Could not find UFC Stats URL for Paul Creighton
# 2025-01-27 15:30:52,704 - WARNING - Could not find UFC Stats URL for Jay Cucciniello
# 2025-01-27 15:30:52,841 - WARNING - Could not find UFC Stats URL for Larry Cureton
# 2025-01-27 15:30:56,396 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Wesley+Correira after 3 retries
# 2025-01-27 15:30:56,970 - WARNING - Could not find UFC Stats URL for Cindy Dandois
# 2025-01-27 15:30:59,634 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=JC+Cottrell after 3 retries
# 2025-01-27 15:31:00,181 - WARNING - Could not find UFC Stats URL for Alexandre Dantas
# 2025-01-27 15:31:01,676 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Alberto+Crane after 3 retries
# 2025-01-27 15:31:02,452 - WARNING - Could not find UFC Stats URL for Sean Daugherty
# 2025-01-27 15:31:04,410 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Dan+Cramer after 3 retries
# 2025-01-27 15:31:04,863 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Jeff+Cox after 3 retries
# 2025-01-27 15:31:05,152 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Marcio+Cruz after 3 retries
# 2025-01-27 15:31:05,244 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Richard+Crunkilton after 3 retries
# 2025-01-27 15:31:05,475 - WARNING - Could not find UFC Stats URL for Mike Davis
# 2025-01-27 15:31:05,645 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Paul+Creighton after 3 retries
# 2025-01-27 15:31:05,824 - WARNING - Could not find UFC Stats URL for Rick Davis
# 2025-01-27 15:31:06,059 - WARNING - Could not find UFC Stats URL for Edilberto de Oliveira
# 2025-01-27 15:31:06,264 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Larry+Cureton after 3 retries
# 2025-01-27 15:31:06,380 - WARNING - Could not find UFC Stats URL for Rodrigo de Lima
# 2025-01-27 15:31:06,527 - WARNING - Could not find UFC Stats URL for Jorge de Oliveira
# 2025-01-27 15:31:06,772 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Jay+Cucciniello after 3 retries
# 2025-01-27 15:31:07,082 - WARNING - Could not find UFC Stats URL for Tom DeBlass
# 2025-01-27 15:31:07,686 - WARNING - Could not find UFC Stats URL for Shane del Rosario
# 2025-01-27 15:31:08,780 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Cindy+Dandois after 3 retries
# 2025-01-27 15:31:09,367 - WARNING - Could not find UFC Stats URL for Jason DeLucia
# 2025-01-27 15:31:15,270 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Alexandre+Dantas after 3 retries
# 2025-01-27 15:31:16,045 - WARNING - Could not find UFC Stats URL for Nick Denis
# 2025-01-27 15:31:17,212 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Sean+Daugherty after 3 retries
# 2025-01-27 15:31:17,767 - WARNING - Could not find UFC Stats URL for Edwin DeWees
# 2025-01-27 15:31:18,558 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Mike+Davis after 3 retries
# 2025-01-27 15:31:18,580 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Jorge+de+Oliveira after 3 retries
# 2025-01-27 15:31:19,168 - WARNING - Could not find UFC Stats URL for Eldo Xavier Dias
# 2025-01-27 15:31:19,348 - WARNING - Could not find UFC Stats URL for David Dodd
# 2025-01-27 15:31:19,951 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Tom+DeBlass after 3 retries
# 2025-01-27 15:31:20,052 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Edilberto+de+Oliveira after 3 retries
# 2025-01-27 15:31:20,777 - WARNING - Could not find UFC Stats URL for Cameron Dollar
# 2025-01-27 15:31:21,760 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Rick+Davis after 3 retries
# 2025-01-27 15:31:21,879 - WARNING - Could not find UFC Stats URL for Houston Dorr
# 2025-01-27 15:31:21,879 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Jason+DeLucia after 3 retries
# 2025-01-27 15:31:22,433 - WARNING - Could not find UFC Stats URL for John Dowdy
# 2025-01-27 15:31:22,511 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Shane+del+Rosario after 3 retries
# 2025-01-27 15:31:22,788 - WARNING - Could not find UFC Stats URL for Antonio Dos Santos
# 2025-01-27 15:31:22,788 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Rodrigo+de+Lima after 3 retries
# 2025-01-27 15:31:23,348 - WARNING - Could not find UFC Stats URL for Robert Drysdale
# 2025-01-27 15:31:23,396 - WARNING - Could not find UFC Stats URL for Derek Downey
# 2025-01-27 15:31:31,382 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Nick+Denis after 3 retries
# 2025-01-27 15:31:31,935 - WARNING - Could not find UFC Stats URL for Hugo Duarte
# 2025-01-27 15:31:33,645 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Edwin+DeWees after 3 retries
# 2025-01-27 15:31:34,233 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=David+Dodd after 3 retries
# 2025-01-27 15:31:34,510 - WARNING - Could not find UFC Stats URL for Milana Dudieva
# 2025-01-27 15:31:34,714 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Eldo+Xavier+Dias after 3 retries
# 2025-01-27 15:31:34,845 - WARNING - Could not find UFC Stats URL for Alexis Dufresne
# 2025-01-27 15:31:35,793 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Houston+Dorr after 3 retries
# 2025-01-27 15:31:36,237 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=John+Dowdy after 3 retries
# 2025-01-27 15:31:36,408 - WARNING - Could not find UFC Stats URL for Kelly Dullanty
# 2025-01-27 15:31:36,569 - WARNING - Could not find UFC Stats URL for Luiz Dutra
# 2025-01-27 15:31:37,078 - WARNING - Could not find UFC Stats URL for Ben Earwood
# 2025-01-27 15:31:37,398 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Cameron+Dollar after 3 retries
# 2025-01-27 15:31:37,777 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Robert+Drysdale after 3 retries
# 2025-01-27 15:31:38,328 - WARNING - Could not find UFC Stats URL for Abdul-Kerim Edilov
# 2025-01-27 15:31:38,542 - WARNING - Could not find UFC Stats URL for Cody East
# 2025-01-27 15:31:39,548 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Derek+Downey after 3 retries
# 2025-01-27 15:31:39,570 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Antonio+Dos+Santos after 3 retries
# 2025-01-27 15:31:40,117 - WARNING - Could not find UFC Stats URL for Tom Egan
# 2025-01-27 15:31:40,364 - WARNING - Could not find UFC Stats URL for Justin Eilers
# 2025-01-27 15:31:48,170 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Milana+Dudieva after 3 retries
# 2025-01-27 15:31:48,728 - WARNING - Could not find UFC Stats URL for Jon Olav Einemo
# 2025-01-27 15:31:48,956 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Hugo+Duarte after 3 retries
# 2025-01-27 15:31:49,510 - WARNING - Could not find UFC Stats URL for Per Eklund
# 2025-01-27 15:31:49,767 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Alexis+Dufresne after 3 retries
# 2025-01-27 15:31:50,338 - WARNING - Could not find UFC Stats URL for Lisa Ellis
# 2025-01-27 15:31:50,670 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Luiz+Dutra after 3 retries
# 2025-01-27 15:31:51,054 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Cody+East after 3 retries
# 2025-01-27 15:31:51,275 - WARNING - Could not find UFC Stats URL for Anna Elmose
# 2025-01-27 15:31:51,937 - WARNING - Could not find UFC Stats URL for Ian Entwistle
# 2025-01-27 15:31:52,997 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Abdul-Kerim+Edilov after 3 retries
# 2025-01-27 15:31:53,795 - WARNING - Could not find UFC Stats URL for Konstantin Erokhin
# 2025-01-27 15:31:53,850 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Ben+Earwood after 3 retries
# 2025-01-27 15:31:53,946 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Kelly+Dullanty after 3 retries
# 2025-01-27 15:31:54,476 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Tom+Egan after 3 retries
# 2025-01-27 15:31:54,499 - WARNING - Could not find UFC Stats URL for Doug Evans
# 2025-01-27 15:31:54,621 - WARNING - Could not find UFC Stats URL for Fred Ettish
# 2025-01-27 15:31:55,058 - WARNING - Could not find UFC Stats URL for Dan Evensen
# 2025-01-27 15:31:55,654 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Justin+Eilers after 3 retries
# 2025-01-27 15:31:56,203 - WARNING - Could not find UFC Stats URL for Edward Faaloloto
# 2025-01-27 15:32:01,224 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Per+Eklund after 3 retries
# 2025-01-27 15:32:01,798 - WARNING - Could not find UFC Stats URL for Ron Faircloth
# 2025-01-27 15:32:04,258 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Lisa+Ellis after 3 retries
# 2025-01-27 15:32:04,813 - WARNING - Could not find UFC Stats URL for Jason Fairn
# 2025-01-27 15:32:07,515 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Jon+Olav+Einemo after 3 retries
# 2025-01-27 15:32:07,731 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Ian+Entwistle after 3 retries
# 2025-01-27 15:32:08,023 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Dan+Evensen after 3 retries
# 2025-01-27 15:32:08,286 - WARNING - Could not find UFC Stats URL for Maiquel Falcao
# 2025-01-27 15:32:08,594 - WARNING - Could not find UFC Stats URL for Brodie Farber
# 2025-01-27 15:32:08,650 - WARNING - Could not find UFC Stats URL for Rinat Fakhretdinov
# 2025-01-27 15:32:08,777 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Anna+Elmose after 3 retries
# 2025-01-27 15:32:08,795 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Fred+Ettish after 3 retries
# 2025-01-27 15:32:09,369 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Doug+Evans after 3 retries
# 2025-01-27 15:32:09,839 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Edward+Faaloloto after 3 retries
# 2025-01-27 15:32:09,891 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Konstantin+Erokhin after 3 retries
# 2025-01-27 15:32:10,364 - WARNING - Could not find UFC Stats URL for Kalindra Faria
# 2025-01-27 15:32:10,384 - WARNING - Could not find UFC Stats URL for Kelly Faszholz
# 2025-01-27 15:32:10,404 - WARNING - Could not find UFC Stats URL for CJ Fernandes
# 2025-01-27 15:32:10,451 - WARNING - Could not find UFC Stats URL for Alexandre Ferreira
# 2025-01-27 15:32:11,001 - WARNING - Could not find UFC Stats URL for Josh Ferguson
# 2025-01-27 15:32:12,907 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Ron+Faircloth after 3 retries
# 2025-01-27 15:32:13,679 - WARNING - Could not find UFC Stats URL for Scott Ferrozzo
# 2025-01-27 15:32:20,418 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Jason+Fairn after 3 retries
# 2025-01-27 15:32:20,985 - WARNING - Could not find UFC Stats URL for Scott Fiedler
# 2025-01-27 15:32:21,219 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Rinat+Fakhretdinov after 3 retries
# 2025-01-27 15:32:21,999 - WARNING - Could not find UFC Stats URL for Colin Fletcher
# 2025-01-27 15:32:22,094 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Maiquel+Falcao after 3 retries
# 2025-01-27 15:32:22,440 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Alexandre+Ferreira after 3 retries
# 2025-01-27 15:32:22,907 - WARNING - Could not find UFC Stats URL for Xavier Foupa-Pokam
# 2025-01-27 15:32:23,326 - WARNING - Could not find UFC Stats URL for Zane Frazier
# 2025-01-27 15:32:25,224 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Kalindra+Faria after 3 retries
# 2025-01-27 15:32:25,242 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Kelly+Faszholz after 3 retries
# 2025-01-27 15:32:25,369 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Brodie+Farber after 3 retries
# 2025-01-27 15:32:25,794 - WARNING - Could not find UFC Stats URL for Ian Freeman
# 2025-01-27 15:32:26,032 - WARNING - Could not find UFC Stats URL for Willamy Freire
# 2025-01-27 15:32:26,127 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Josh+Ferguson after 3 retries
# 2025-01-27 15:32:26,153 - WARNING - Could not find UFC Stats URL for Don Frye
# 2025-01-27 15:32:27,030 - WARNING - Could not find UFC Stats URL for Tony Fryklund
# 2025-01-27 15:32:27,464 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Scott+Ferrozzo after 3 retries
# 2025-01-27 15:32:27,645 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=CJ+Fernandes after 3 retries
# 2025-01-27 15:32:28,025 - WARNING - Could not find UFC Stats URL for Katsuhisa Fujii
# 2025-01-27 15:32:28,217 - WARNING - Could not find UFC Stats URL for Travis Fulton
# 2025-01-27 15:32:37,376 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Scott+Fiedler after 3 retries
# 2025-01-27 15:32:37,431 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Don+Frye after 3 retries
# 2025-01-27 15:32:37,592 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Zane+Frazier after 3 retries
# 2025-01-27 15:32:37,998 - WARNING - Could not find UFC Stats URL for Sheila Gaff
# 2025-01-27 15:32:38,299 - WARNING - Could not find UFC Stats URL for Sam Fulton
# 2025-01-27 15:32:38,603 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Colin+Fletcher after 3 retries
# 2025-01-27 15:32:38,756 - WARNING - Could not find UFC Stats URL for Dave Galera
# 2025-01-27 15:32:39,181 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Xavier+Foupa-Pokam after 3 retries
# 2025-01-27 15:32:39,183 - WARNING - Could not find UFC Stats URL for Tom Gallicchio
# 2025-01-27 15:32:39,829 - WARNING - Could not find UFC Stats URL for Joey Gambino
# 2025-01-27 15:32:40,300 - ERROR - Failed to fetch https://www.ufc.com/athlete/willamy-freire after 3 retries
# 2025-01-27 15:32:40,890 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Tony+Fryklund after 3 retries
# 2025-01-27 15:32:41,472 - WARNING - Could not find UFC Stats URL for Sean Gannon
# 2025-01-27 15:32:43,242 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Ian+Freeman after 3 retries
# 2025-01-27 15:32:43,816 - WARNING - Could not find UFC Stats URL for Azamat Gashimov
# 2025-01-27 15:32:44,972 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Katsuhisa+Fujii after 3 retries
# 2025-01-27 15:32:45,860 - WARNING - Could not find UFC Stats URL for Brian Gassaway
# 2025-01-27 15:32:48,940 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Travis+Fulton after 3 retries
# 2025-01-27 15:32:50,052 - WARNING - Could not find UFC Stats URL for Paul Georgieff
# 2025-01-27 15:32:50,849 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Willamy+Freire after 3 retries
# 2025-01-27 15:32:51,342 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Sheila+Gaff after 3 retries
# 2025-01-27 15:32:52,252 - WARNING - Could not find UFC Stats URL for Darrel Gholar
# 2025-01-27 15:32:52,790 - WARNING - Could not find UFC Stats URL for Brian Geraghty
# 2025-01-27 15:32:53,275 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Tom+Gallicchio after 3 retries
# 2025-01-27 15:32:53,855 - WARNING - Could not find UFC Stats URL for Tiki Ghosn
# 2025-01-27 15:32:53,875 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Sam+Fulton after 3 retries
# 2025-01-27 15:32:54,741 - WARNING - Could not find UFC Stats URL for James Giboo
# 2025-01-27 15:32:55,735 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Joey+Gambino after 3 retries
# 2025-01-27 15:32:56,600 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Sean+Gannon after 3 retries
# 2025-01-27 15:32:57,172 - WARNING - Could not find UFC Stats URL for Joseph Gigliotti
# 2025-01-27 15:32:57,392 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Dave+Galera after 3 retries
# 2025-01-27 15:32:57,948 - WARNING - Could not find UFC Stats URL for Joey Gilbert
# 2025-01-27 15:32:58,092 - WARNING - Could not find UFC Stats URL for Lance Gibson
# 2025-01-27 15:32:58,645 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Azamat+Gashimov after 3 retries
# 2025-01-27 15:32:59,269 - WARNING - Could not find UFC Stats URL for Jason Gilliam
# 2025-01-27 15:33:04,003 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Brian+Gassaway after 3 retries
# 2025-01-27 15:33:05,148 - WARNING - Could not find UFC Stats URL for Bob Gilstrap
# 2025-01-27 15:33:05,785 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Paul+Georgieff after 3 retries
# 2025-01-27 15:33:06,422 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Brian+Geraghty after 3 retries
# 2025-01-27 15:33:06,569 - WARNING - Could not find UFC Stats URL for He-Man Gipson
# 2025-01-27 15:33:06,970 - WARNING - Could not find UFC Stats URL for Jason Godsey
# 2025-01-27 15:33:10,396 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Darrel+Gholar after 3 retries
# 2025-01-27 15:33:10,844 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Jason+Gilliam after 3 retries
# 2025-01-27 15:33:10,949 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Tiki+Ghosn after 3 retries
# 2025-01-27 15:33:11,506 - WARNING - Could not find UFC Stats URL for Lewis Gonzalez
# 2025-01-27 15:33:11,506 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=James+Giboo after 3 retries
# 2025-01-27 15:33:11,703 - WARNING - Could not find UFC Stats URL for Ulysses Gomez
# 2025-01-27 15:33:12,078 - WARNING - Could not find UFC Stats URL for Pearl Gonzalez
# 2025-01-27 15:33:12,354 - WARNING - Could not find UFC Stats URL for Allan Goes
# 2025-01-27 15:33:12,819 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Joseph+Gigliotti after 3 retries
# 2025-01-27 15:33:13,619 - WARNING - Could not find UFC Stats URL for Gary Goodridge
# 2025-01-27 15:33:14,817 - ERROR - Failed to fetch https://www.ufc.com/athlete/lance-gibson after 3 retries
# 2025-01-27 15:33:17,338 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Joey+Gilbert after 3 retries
# 2025-01-27 15:33:19,481 - WARNING - Could not find UFC Stats URL for Tim Gorman
# 2025-01-27 15:33:22,568 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Bob+Gilstrap after 3 retries
# 2025-01-27 15:33:23,376 - WARNING - Could not find UFC Stats URL for Chase Gormley
# 2025-01-27 15:33:25,483 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Pearl+Gonzalez after 3 retries
# 2025-01-27 15:33:26,309 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=He-Man+Gipson after 3 retries
# 2025-01-27 15:33:26,320 - WARNING - Could not find UFC Stats URL for Royce Gracie
# 2025-01-27 15:33:26,761 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Ulysses+Gomez after 3 retries
# 2025-01-27 15:33:26,869 - WARNING - Could not find UFC Stats URL for Renzo Gracie
# 2025-01-27 15:33:27,166 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Lance+Gibson after 3 retries
# 2025-01-27 15:33:27,581 - WARNING - Could not find UFC Stats URL for Rolles Gracie
# 2025-01-27 15:33:28,118 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Lewis+Gonzalez after 3 retries
# 2025-01-27 15:33:28,272 - WARNING - Could not find UFC Stats URL for Steven Graham
# 2025-01-27 15:33:28,295 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Gary+Goodridge after 3 retries
# 2025-01-27 15:33:28,936 - WARNING - Could not find UFC Stats URL for Neil Grove
# 2025-01-27 15:33:28,997 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Allan+Goes after 3 retries
# 2025-01-27 15:33:29,024 - WARNING - Could not find UFC Stats URL for Nandor Guelmino
# 2025-01-27 15:33:30,294 - ERROR - Failed to fetch https://www.ufc.com/athlete/jason-godsey after 3 retries
# 2025-01-27 15:33:30,549 - WARNING - Could not find UFC Stats URL for Leonardo Guimaraes
# 2025-01-27 15:33:36,567 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Tim+Gorman after 3 retries
# 2025-01-27 15:33:37,126 - WARNING - Could not find UFC Stats URL for Brad Gumm
# 2025-01-27 15:33:39,819 - ERROR - Failed to fetch https://www.ufc.com/athlete/chase-gormley after 3 retries
# 2025-01-27 15:33:41,900 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Jason+Godsey after 3 retries
# 2025-01-27 15:33:42,728 - WARNING - Could not find UFC Stats URL for Fabio Gurgel
# 2025-01-27 15:33:43,287 - ERROR - Failed to fetch https://www.ufc.com/athlete/steven-graham after 3 retries
# 2025-01-27 15:33:43,505 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Neil+Grove after 3 retries
# 2025-01-27 15:33:44,173 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Rolles+Gracie after 3 retries
# 2025-01-27 15:33:44,351 - WARNING - Could not find UFC Stats URL for Andre Gusmao
# 2025-01-27 15:33:44,723 - WARNING - Could not find UFC Stats URL for Horacio Gutierrez
# 2025-01-27 15:33:44,762 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Nandor+Guelmino after 3 retries
# 2025-01-27 15:33:45,470 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Leonardo+Guimaraes after 3 retries
# 2025-01-27 15:33:45,589 - WARNING - Could not find UFC Stats URL for Keith Hackney
# 2025-01-27 15:33:46,346 - WARNING - Could not find UFC Stats URL for Mark Hall
# 2025-01-27 15:33:46,436 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Royce+Gracie after 3 retries
# 2025-01-27 15:33:47,180 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Renzo+Gracie after 3 retries
# 2025-01-27 15:33:47,258 - WARNING - Could not find UFC Stats URL for Tony Halme
# 2025-01-27 15:33:47,778 - WARNING - Could not find UFC Stats URL for John Halverson
# 2025-01-27 15:33:54,325 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Brad+Gumm after 3 retries
# 2025-01-27 15:33:54,910 - WARNING - Could not find UFC Stats URL for Frank Hamaker
# 2025-01-27 15:33:55,536 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Chase+Gormley after 3 retries
# 2025-01-27 15:33:56,371 - WARNING - Could not find UFC Stats URL for James Hammortree
# 2025-01-27 15:33:58,081 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Fabio+Gurgel after 3 retries
# 2025-01-27 15:33:58,655 - WARNING - Could not find UFC Stats URL for Gerry Harris
# 2025-01-27 15:33:59,252 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Steven+Graham after 3 retries
# 2025-01-27 15:33:59,813 - WARNING - Could not find UFC Stats URL for Collin Hart
# 2025-01-27 15:33:59,813 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Horacio+Gutierrez after 3 retries
# ...
# 2025-01-27 15:35:23,240 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Wallid+Ismail after 3 retries
# 2025-01-27 15:35:24,395 - WARNING - Could not find UFC Stats URL for Chan-Mi Jeon
# 2025-01-27 15:35:26,793 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Eugene+Jackson after 3 retries
# 2025-01-27 15:35:27,972 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Yoislandy+Izquierdo after 3 retries
# 2025-01-27 15:35:28,846 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Jeremy+Jackson after 3 retries
# 2025-01-27 15:35:28,946 - WARNING - Could not find UFC Stats URL for Maciej Jewtuszko
# 2025-01-27 15:35:29,230 - WARNING - Could not find UFC Stats URL for Ronald Jhun
# 2025-01-27 15:35:29,579 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Kevin+Jackson after 3 retries
# 2025-01-27 15:35:29,709 - WARNING - Could not find UFC Stats URL for Phil Johns
# 2025-01-27 15:35:30,730 - WARNING - Could not find UFC Stats URL for Dashon Johnson
# 2025-01-27 15:35:33,538 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Mike+Jackson after 3 retries
# 2025-01-27 15:35:34,915 - WARNING - Could not find UFC Stats URL for Brian Johnston
# 2025-01-27 15:35:35,292 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Trent+Jenkins after 3 retries
# 2025-01-27 15:35:35,340 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Justin+James after 3 retries
# 2025-01-27 15:35:35,911 - WARNING - Could not find UFC Stats URL for Marcus Jones
# 2025-01-27 15:35:37,491 - WARNING - Could not find UFC Stats URL for Paul Jones
# 2025-01-27 15:35:38,972 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Steve+Jennum after 3 retries
# 2025-01-27 15:35:39,521 - WARNING - Could not find UFC Stats URL for Justin Jones
# 2025-01-27 15:35:40,366 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Brock+Jardine after 3 retries
# 2025-01-27 15:35:40,930 - WARNING - Could not find UFC Stats URL for Kevin Jordan
# 2025-01-27 15:35:42,034 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Chan-Mi+Jeon after 3 retries
# 2025-01-27 15:35:42,590 - WARNING - Could not find UFC Stats URL for Joe Jordan
# 2025-01-27 15:35:45,329 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Phil+Johns after 3 retries
# 2025-01-27 15:35:46,141 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Maciej+Jewtuszko after 3 retries
# 2025-01-27 15:35:46,240 - WARNING - Could not find UFC Stats URL for Jeff Joslin
# 2025-01-27 15:35:46,964 - WARNING - Could not find UFC Stats URL for Steve Judson
# 2025-01-27 15:35:47,889 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Dashon+Johnson after 3 retries
# 2025-01-27 15:35:48,319 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Ronald+Jhun after 3 retries
# 2025-01-27 15:35:48,460 - WARNING - Could not find UFC Stats URL for Scott Junk
# 2025-01-27 15:35:49,225 - WARNING - Could not find UFC Stats URL for Emily Kagan
# 2025-01-27 15:35:49,283 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Brian+Johnston after 3 retries
# 2025-01-27 15:35:50,427 - WARNING - Could not find UFC Stats URL for Sirwan Kakai
# 2025-01-27 15:35:53,672 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Paul+Jones after 3 retries
# 2025-01-27 15:35:54,249 - WARNING - Could not find UFC Stats URL for Geza Kalman
# 2025-01-27 15:35:54,272 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Marcus+Jones after 3 retries
# 2025-01-27 15:35:54,825 - WARNING - Could not find UFC Stats URL for David Kaplan
# 2025-01-27 15:35:55,683 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Justin+Jones after 3 retries
# 2025-01-27 15:35:56,838 - WARNING - Could not find UFC Stats URL for Yusuke Kasuya
# 2025-01-27 15:35:57,209 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Joe+Jordan after 3 retries
# 2025-01-27 15:35:57,832 - WARNING - Could not find UFC Stats URL for Julie Kedzie
# 2025-01-27 15:36:00,375 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Steve+Judson after 3 retries
# 2025-01-27 15:36:01,213 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Kevin+Jordan after 3 retries
# 2025-01-27 15:36:01,574 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Jeff+Joslin after 3 retries
# 2025-01-27 15:36:01,788 - WARNING - Could not find UFC Stats URL for Steve Kennedy
# 2025-01-27 15:36:02,376 - WARNING - Could not find UFC Stats URL for Mark Kerr
# 2025-01-27 15:36:04,112 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Emily+Kagan after 3 retries
# 2025-01-27 15:36:04,163 - WARNING - Could not find UFC Stats URL for CJ Keith
# 2025-01-27 15:36:04,664 - WARNING - Could not find UFC Stats URL for Sanae Kikuta
# 2025-01-27 15:36:05,010 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Scott+Junk after 3 retries
# 2025-01-27 15:36:05,905 - WARNING - Could not find UFC Stats URL for Mike King
# 2025-01-27 15:36:06,719 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Sirwan+Kakai after 3 retries
# 2025-01-27 15:36:07,286 - WARNING - Could not find UFC Stats URL for Koji Kitao
# 2025-01-27 15:36:09,499 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=David+Kaplan after 3 retries
# 2025-01-27 15:36:10,655 - WARNING - Could not find UFC Stats URL for Brad Kohler
# 2025-01-27 15:36:11,944 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Geza+Kalman after 3 retries
# 2025-01-27 15:36:12,512 - WARNING - Could not find UFC Stats URL for Tsuyoshi Kohsaka
# 2025-01-27 15:36:14,121 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Julie+Kedzie after 3 retries
# 2025-01-27 15:36:14,890 - WARNING - Could not find UFC Stats URL for John Kolosci
# 2025-01-27 15:36:16,021 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Yusuke+Kasuya after 3 retries
# 2025-01-27 15:36:17,481 - WARNING - Could not find UFC Stats URL for Yuki Kondo
# 2025-01-27 15:36:18,082 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Mark+Kerr after 3 retries
# 2025-01-27 15:36:18,442 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Steve+Kennedy after 3 retries
# 2025-01-27 15:36:18,726 - WARNING - Could not find UFC Stats URL for Pascal Krauss
# 2025-01-27 15:36:18,855 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=CJ+Keith after 3 retries
# 2025-01-27 15:36:19,789 - WARNING - Could not find UFC Stats URL for Leo Kuntz
# 2025-01-27 15:36:20,216 - WARNING - Could not find UFC Stats URL for Keigo Kunihara
# 2025-01-27 15:36:22,179 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Koji+Kitao after 3 retries
# 2025-01-27 15:36:22,989 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Mike+King after 3 retries
# 2025-01-27 15:36:23,094 - WARNING - Could not find UFC Stats URL for Tina Lahdemaki
# 2025-01-27 15:36:23,462 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Sanae+Kikuta after 3 retries
# 2025-01-27 15:36:23,546 - WARNING - Could not find UFC Stats URL for Tim Lajcik
# 2025-01-27 15:36:24,341 - WARNING - Could not find UFC Stats URL for Austen Lane
# 2025-01-27 15:36:25,437 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Brad+Kohler after 3 retries
# 2025-01-27 15:36:25,996 - WARNING - Could not find UFC Stats URL for Anthony Lapsley
# 2025-01-27 15:36:30,817 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=John+Kolosci after 3 retries
# 2025-01-27 15:36:32,216 - WARNING - Could not find UFC Stats URL for Icho Larenas
# 2025-01-27 15:36:33,499 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Tsuyoshi+Kohsaka after 3 retries
# 2025-01-27 15:36:34,069 - WARNING - Could not find UFC Stats URL for Sione Latu
# 2025-01-27 15:36:35,105 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Keigo+Kunihara after 3 retries
# 2025-01-27 15:36:35,499 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Yuki+Kondo after 3 retries
# 2025-01-27 15:36:35,525 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Pascal+Krauss after 3 retries
# 2025-01-27 15:36:35,961 - WARNING - Could not find UFC Stats URL for Dan Lauzon
# 2025-01-27 15:36:37,549 - WARNING - Could not find UFC Stats URL for David Lee
# 2025-01-27 15:36:37,845 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Tim+Lajcik after 3 retries
# 2025-01-27 15:36:38,185 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Tina+Lahdemaki after 3 retries
# 2025-01-27 15:36:38,423 - WARNING - Could not find UFC Stats URL for Jackie Lee
# 2025-01-27 15:36:38,626 - WARNING - Could not find UFC Stats URL for James Lee
# 2025-01-27 15:36:38,876 - WARNING - Could not find UFC Stats URL for Rocky Lee
# 2025-01-27 15:36:39,090 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Leo+Kuntz after 3 retries
# 2025-01-27 15:36:39,634 - WARNING - Could not find UFC Stats URL for Christophe Leninger
# 2025-01-27 15:36:40,692 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Austen+Lane after 3 retries
# 2025-01-27 15:36:40,734 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Anthony+Lapsley after 3 retries
# 2025-01-27 15:36:41,245 - WARNING - Could not find UFC Stats URL for Alberta Cerra Leon
# 2025-01-27 15:36:41,293 - WARNING - Could not find UFC Stats URL for Kimo Leopoldo
# 2025-01-27 15:36:43,890 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Icho+Larenas after 3 retries
# 2025-01-27 15:36:44,729 - WARNING - Could not find UFC Stats URL for Frank Lester
# 2025-01-27 15:36:48,779 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Sione+Latu after 3 retries
# 2025-01-27 15:36:49,659 - WARNING - Could not find UFC Stats URL for Justin Levens
# 2025-01-27 15:36:52,081 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Rocky+Lee after 3 retries
# 2025-01-27 15:36:53,269 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Christophe+Leninger after 3 retries
# 2025-01-27 15:36:53,338 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Dan+Lauzon after 3 retries
# 2025-01-27 15:36:53,789 - WARNING - Could not find UFC Stats URL for David Levicki
# 2025-01-27 15:36:53,883 - WARNING - Could not find UFC Stats URL for Jess Liaudin
# 2025-01-27 15:36:54,160 - WARNING - Could not find UFC Stats URL for John Lewis
# 2025-01-27 15:36:55,963 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=David+Lee after 3 retries
# 2025-01-27 15:36:56,002 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Jackie+Lee after 3 retries
# 2025-01-27 15:36:56,575 - WARNING - Could not find UFC Stats URL for Chris Liguori
# 2025-01-27 15:36:56,777 - WARNING - Could not find UFC Stats URL for Zach Light
# 2025-01-27 15:36:57,357 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Frank+Lester after 3 retries
# 2025-01-27 15:36:58,249 - WARNING - Could not find UFC Stats URL for Jake Lindsey
# 2025-01-27 15:36:59,595 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Kimo+Leopoldo after 3 retries
# 2025-01-27 15:37:00,004 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Alberta+Cerra+Leon after 3 retries
# 2025-01-27 15:37:00,149 - WARNING - Could not find UFC Stats URL for Lucio Linhares
# 2025-01-27 15:37:00,610 - WARNING - Could not find UFC Stats URL for Abner Lloveras
# 2025-01-27 15:37:02,478 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=James+Lee after 3 retries
# 2025-01-27 15:37:03,358 - WARNING - Could not find UFC Stats URL for John Lober
# 2025-01-27 15:37:07,146 - ERROR - Failed to fetch https://www.ufc.com/athlete/justin-levens after 3 retries
# 2025-01-27 15:37:11,051 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=David+Levicki after 3 retries
# 2025-01-27 15:37:11,631 - WARNING - Could not find UFC Stats URL for Dileno Lopes
# 2025-01-27 15:37:13,388 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Jess+Liaudin after 3 retries
# 2025-01-27 15:37:13,513 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Zach+Light after 3 retries
# 2025-01-27 15:37:13,814 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=John+Lewis after 3 retries
# 2025-01-27 15:37:14,085 - WARNING - Could not find UFC Stats URL for Jorge Lopez
# 2025-01-27 15:37:14,270 - WARNING - Could not find UFC Stats URL for Steve Lopez
# 2025-01-27 15:37:14,406 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Abner+Lloveras after 3 retries
# 2025-01-27 15:37:14,574 - WARNING - Could not find UFC Stats URL for Nate Loughran
# 2025-01-27 15:37:14,995 - WARNING - Could not find UFC Stats URL for Ian Loveland
# 2025-01-27 15:37:15,483 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Chris+Liguori after 3 retries
# 2025-01-27 15:37:16,400 - WARNING - Could not find UFC Stats URL for Waylon Lowe
# 2025-01-27 15:37:17,451 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Jake+Lindsey after 3 retries
# 2025-01-27 15:37:18,014 - WARNING - Could not find UFC Stats URL for Robert Lucarelli
# 2025-01-27 15:37:18,341 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Lucio+Linhares after 3 retries
# 2025-01-27 15:37:19,390 - WARNING - Could not find UFC Stats URL for Matt Lucas
# 2025-01-27 15:37:19,473 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=John+Lober after 3 retries
# 2025-01-27 15:37:20,032 - WARNING - Could not find UFC Stats URL for Mike Lullo
# 2025-01-27 15:37:21,497 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Justin+Levens after 3 retries
# 2025-01-27 15:37:22,376 - WARNING - Could not find UFC Stats URL for Thaddeus Luster
# 2025-01-27 15:37:25,329 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Dileno+Lopes after 3 retries
# 2025-01-27 15:37:25,882 - WARNING - Could not find UFC Stats URL for Stevie Lynch
# 2025-01-27 15:37:28,568 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Jorge+Lopez after 3 retries
# 2025-01-27 15:37:30,714 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Nate+Loughran after 3 retries
# 2025-01-27 15:37:31,397 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Steve+Lopez after 3 retries
# 2025-01-27 15:37:31,704 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Robert+Lucarelli after 3 retries
# 2025-01-27 15:37:32,307 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Waylon+Lowe after 3 retries
# 2025-01-27 15:37:33,219 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Ian+Loveland after 3 retries
# 2025-01-27 15:37:35,880 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Matt+Lucas after 3 retries
# 2025-01-27 15:37:37,934 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Mike+Lullo after 3 retries
# 2025-01-27 15:37:38,143 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Stevie+Lynch after 3 retries
# 2025-01-27 15:37:38,243 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Thaddeus+Luster after 3 retries
# 2025-01-27 15:37:38,249 - INFO - Fighter details saved to data/fighter_details.csv.
