# %%
#!/usr/bin/env python
# coding: utf-8

# imports
import pandas as pd
from tqdm.notebook import tqdm_notebook
import aiohttp
import asyncio
from bs4 import BeautifulSoup
import scrape_ufc_stats_library as LIB
import yaml
import nest_asyncio
import time
import random
import os
from scrape_ufc_stats_library import parse_fight_results_and_stats_async

# %%
# Apply nest_asyncio to allow nested event loops
nest_asyncio.apply()

# %%
# Load configuration
config = yaml.safe_load(open('scrape_ufc_stats_config.yaml'))

# %%
# Load existing fight details
existing_fight_file = config['fight_details_file_name']
if os.path.exists(existing_fight_file):
    existing_fights_df = pd.read_csv(existing_fight_file)
    existing_fight_urls = set(existing_fights_df['URL'])
else:
    existing_fight_urls = set()

# Load scraped progress file
progress_file = config['scraped_progress_file']
if os.path.exists(progress_file):
    progress_df = pd.read_csv(progress_file)
    completed_fights = set(progress_df[progress_df["TYPE"] == "fight"]["URL"])
else:
    completed_fights = set()

# Get fight URLs
# Ensure all URLs are valid strings and not placeholders like '...'
all_fight_urls = [...]  # Populate dynamically

new_fight_urls = [
    url for url in all_fight_urls
    if isinstance(url, str) and url.startswith("http") and url not in existing_fight_urls and url not in completed_fights
]

# Print a few URLs to verify
print(f"✅ Valid fight URLs to scrape: {new_fight_urls[:5]}")


new_fight_urls = [url for url in all_fight_urls if url not in existing_fight_urls and url not in completed_fights]

async def scrape_fights():
    soups = await LIB.fetch_all_soups(new_fight_urls)
    for url, soup in zip(new_fight_urls, soups):
        if soup:
            # Process fight data (replace with actual parsing function)
            save_progress("fight", url, config)

asyncio.run(scrape_fights())
# Out:
# ✅ Valid fight URLs to scrape: []
# Error fetching URL: Ellipsis, attempt 1
# Error fetching URL: Ellipsis, attempt 2
# Error fetching URL: Ellipsis, attempt 3
# Error fetching URL: Ellipsis, attempt 1
# Error fetching URL: Ellipsis, attempt 2
# Error fetching URL: Ellipsis, attempt 3
# Error fetching URL: Ellipsis, attempt 1
# Error fetching URL: Ellipsis, attempt 2
# Error fetching URL: Ellipsis, attempt 3
# ❌ Failed to fetch event page: Ellipsis

# %%
# Asynchronous get_soup replacement
async def get_soup_async(url, session, retries=3):
    for attempt in range(retries):
        try:
            async with session.get(url) as response:
                if response.status == 200:
                    html = await response.text()
                    return BeautifulSoup(html, 'html.parser')
                elif response.status == 429:  # Too Many Requests
                    print(f"Rate-limited on {url}. Retrying in {2 ** attempt} seconds...")
                    await asyncio.sleep(2 ** attempt)  # Exponential backoff
        except Exception as e:
            print(f"Error fetching URL: {url}, attempt {attempt + 1}")
    print(f"Failed to fetch URL after {retries} attempts: {url}")
    return None

# %%
# Fetch multiple soups concurrently
async def fetch_all_soups(urls):
    connector = aiohttp.TCPConnector(limit=5)  # Limit simultaneous requests
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
    }
    async with aiohttp.ClientSession(connector=connector, headers=headers) as session:
        soups = []
        for url in urls:
            soup = await get_soup_async(url, session)
            soups.append(soup)
            # Add a random delay between 1 and 3 seconds
            await asyncio.sleep(random.uniform(1, 3))
        return soups

# %%
# Fallback mechanism for missing data
def use_backup_scraper(url, column_names):
    # Replace this with the backup scraper logic for the relevant data
    # For now, return a placeholder DataFrame
    backup_data = pd.DataFrame(columns=column_names)
    # Example: fetch data from Sherdog, UFC Athletes, or other sources
    backup_data.loc[0] = ["Backup Value"] * len(column_names)
    return backup_data

# %%
# Ensure an event loop is available
try:
    loop = asyncio.get_running_loop()
except RuntimeError:
    loop = asyncio.new_event_loop()
    asyncio.set_event_loop(loop)

# %%
# ## Parse Event Details
# Includes: Event, URL, Date, Location

# Define URL to parse
events_url = config['completed_events_all_url']

# Fetch and parse event details
soup = LIB.get_soup(events_url)
raw_event_details_df = LIB.parse_event_details(soup)

# Load existing event details
existing_event_file = config['event_details_file_name']
if os.path.exists(existing_event_file):
    existing_event_details_df = pd.read_csv(existing_event_file)
    existing_event_urls = set(existing_event_details_df['URL'])
else:
    existing_event_details_df = pd.DataFrame(columns=raw_event_details_df.columns)
    existing_event_urls = set()

# Identify new events
new_events_df = raw_event_details_df[~raw_event_details_df['URL'].isin(existing_event_urls)]

# Append new events to the dataset (newest events first)
if not new_events_df.empty:
    full_event_details_df = pd.concat([new_events_df, existing_event_details_df], ignore_index=True)
    full_event_details_df.to_csv(existing_event_file, index=False)
else:
    full_event_details_df = existing_event_details_df

# **Always Display All Event Data**
display(full_event_details_df)
# Out:
#                                       EVENT  \
# 0      UFC Fight Night: Adesanya vs. Imavov
# 1            UFC 311: Makhachev vs. Moicano
# 2         UFC Fight Night: Dern vs. Ribas 2
# 3    UFC Fight Night: Covington vs. Buckley
# 4              UFC 310: Pantoja vs. Asakura
# ..                                      ...
# 713              UFC 6: Clash of the Titans
# 714          UFC 5: The Return of the Beast
# 715          UFC 4: Revenge of the Warriors
# 716               UFC 3: The American Dream
# 717                       UFC 2: No Way Out
#
#                                                    URL                DATE  \
# 0    http://ufcstats.com/event-details/80dbeb1dd5b5...   February 01, 2025
# 1    http://ufcstats.com/event-details/39f68882def7...    January 18, 2025
# 2    http://ufcstats.com/event-details/81ddc98fceb3...    January 11, 2025
# 3    http://ufcstats.com/event-details/72c9c2eadfc3...   December 14, 2024
# 4    http://ufcstats.com/event-details/ad23903ef3af...   December 07, 2024
# ..                                                 ...                 ...
# 713  http://ufcstats.com/event-details/1c3f5e85b59e...       July 14, 1995
# 714  http://ufcstats.com/event-details/dedc3bb440d0...      April 07, 1995
# 715  http://ufcstats.com/event-details/b60391da771d...   December 16, 1994
# 716  http://ufcstats.com/event-details/1a49e0670dfa...  September 09, 1994
# 717  http://ufcstats.com/event-details/a6a9ab5a824e...      March 11, 1994
#
#                            LOCATION
# 0      Riyadh, Riyadh, Saudi Arabia
# 1        Inglewood, California, USA
# 2            Las Vegas, Nevada, USA
# 3               Tampa, Florida, USA
# 4            Las Vegas, Nevada, USA
# ..                              ...
# 713            Casper, Wyoming, USA
# 714  Charlotte, North Carolina, USA
# 715            Tulsa, Oklahoma, USA
# 716  Charlotte, North Carolina, USA
# 717           Denver, Colorado, USA
#
# [718 rows x 4 columns]

# %%
# Ensure "data" folder exists before doing anything
os.makedirs("data", exist_ok=True)

# ✅ Step 1: Run Event Scraper First
events_url = config['completed_events_all_url']
soup = LIB.get_soup(events_url)
raw_event_details_df = LIB.parse_event_details(soup)

# ✅ Step 2: Load Existing Events (For Incremental Updates)
existing_event_file = os.path.join("data", config['event_details_file_name'])

if os.path.exists(existing_event_file):
    existing_event_details_df = pd.read_csv(existing_event_file)
    existing_event_urls = set(existing_event_details_df['URL'])
else:
    existing_event_details_df = pd.DataFrame(columns=raw_event_details_df.columns)
    existing_event_urls = set()

# ✅ Step 3: Identify New Events
new_events_df = raw_event_details_df[~raw_event_details_df['URL'].isin(existing_event_urls)]

if not new_events_df.empty:
    full_event_details_df = pd.concat([new_events_df, existing_event_details_df], ignore_index=True)
    full_event_details_df.to_csv(existing_event_file, index=False)
    print(f"✅ {len(new_events_df)} new events added.")
else:
    full_event_details_df = existing_event_details_df
    print("⚠️ No new events detected. Skipping event updates.")

# ✅ Step 4: Extract Fight URLs From Events
list_of_events_urls = list(full_event_details_df['URL'])

# ✅ Step 5: Load Existing Fight Details Before Scraping
existing_fight_details_file = os.path.join("data", config['fight_details_file_name'])

if os.path.exists(existing_fight_details_file):
    existing_fight_details_df = pd.read_csv(existing_fight_details_file)
    existing_fight_urls = set(existing_fight_details_df['URL'])
else:
    existing_fight_details_df = pd.DataFrame(columns=config['fight_details_column_names'])
    existing_fight_urls = set()

# ✅ Step 6: Fetch Fight URLs from New Events
all_fight_details_df = asyncio.run(
    LIB.parse_fight_details_async(list_of_events_urls, existing_fight_urls, config)
)

# ✅ Step 7: Extract New Fight URLs
all_fight_urls = list(all_fight_details_df['URL'])
new_fight_urls = [
    url for url in all_fight_urls
    if isinstance(url, str) and url.startswith("http") and url not in existing_fight_urls
]

if not new_fight_urls:
    print("✅ No new fights to scrape. Exiting early.")
else:
    print(f"🆕 {len(new_fight_urls)} new fights detected. Starting scraping process.")
# Out:
# ⚠️ No new events detected. Skipping event updates.
# ✅ No new fights to scrape. Exiting early.

# %%
# ## Parse Fight Details
# Includes: EVENT, BOUT, URL

# Define list of event URLs to parse
list_of_events_urls = list(full_event_details_df['URL'])

# Load existing fight details BEFORE running the async function
existing_fight_details_file = config['fight_details_file_name']
if os.path.exists(existing_fight_details_file):
    existing_fight_details_df = pd.read_csv(existing_fight_details_file)
    existing_fight_urls = set(existing_fight_details_df['URL'])  # ✅ Defined before calling function
else:
    existing_fight_details_df = pd.DataFrame(columns=config['fight_details_column_names'])
    existing_fight_urls = set()  # ✅ Empty set to prevent errors

# Fetch fight details asynchronously with all required arguments
all_fight_details_df = loop.run_until_complete(
    LIB.parse_fight_details_async(list_of_events_urls, existing_fight_urls, config)
)

# Identify new fight details
new_fight_details_df = all_fight_details_df[~all_fight_details_df['URL'].isin(existing_fight_urls)]

# Append new fight details to the dataset (newest first)
if not new_fight_details_df.empty:
    full_fight_details_df = pd.concat([new_fight_details_df, existing_fight_details_df], ignore_index=True)
    full_fight_details_df.to_csv(existing_fight_details_file, index=False)
else:
    full_fight_details_df = existing_fight_details_df

# **Always Display All Fight Details Data**
display(full_fight_details_df)
# Out:
#                                      EVENT  \
# 0     UFC Fight Night: Adesanya vs. Imavov
# 1     UFC Fight Night: Adesanya vs. Imavov
# 2     UFC Fight Night: Adesanya vs. Imavov
# 3     UFC Fight Night: Adesanya vs. Imavov
# 4     UFC Fight Night: Adesanya vs. Imavov
# ...                                    ...
# 8007                     UFC 2: No Way Out
# 8008                     UFC 2: No Way Out
# 8009                     UFC 2: No Way Out
# 8010                     UFC 2: No Way Out
# 8011                     UFC 2: No Way Out
#
#                                             BOUT  \
# 0         Nassourdine Imavov vs. Israel Adesanya
# 1               Michael Page vs. Shara Magomedov
# 2     Sergei Pavlovich vs. Jairzinho Rozenstruik
# 3        Vinicius Oliveira vs. Said Nurmagomedov
# 4                      Fares Ziam vs. Mike Davis
# ...                                          ...
# 8007           Orlando Wiet vs. Robert Lucarelli
# 8008           Frank Hamaker vs. Thaddeus Luster
# 8009             Johnny Rhodes vs. David Levicki
# 8010                Patrick Smith vs. Ray Wizard
# 8011             Scott Morris vs. Sean Daugherty
#
#                                                     URL
# 0     http://ufcstats.com/fight-details/85e79748b75e...
# 1     http://ufcstats.com/fight-details/426e7a3de681...
# 2     http://ufcstats.com/fight-details/3c00f34f20c8...
# 3     http://ufcstats.com/fight-details/70b8dca3addc...
# 4     http://ufcstats.com/fight-details/775788423f5e...
# ...                                                 ...
# 8007  http://ufcstats.com/fight-details/3b020d4914b4...
# 8008  http://ufcstats.com/fight-details/d917c8c7461b...
# 8009  http://ufcstats.com/fight-details/ccee020be2e8...
# 8010  http://ufcstats.com/fight-details/4b9ae533ccb3...
# 8011  http://ufcstats.com/fight-details/4acab67848e7...
#
# [8012 rows x 3 columns]

# %%
# ## Parse Fight Results and Stats
# Includes Fight Results and Fight Stats

# Define list of fight URLs to parse
list_of_fight_details_urls = list(full_fight_details_df['URL'])

# Fetch fight results and stats asynchronously
all_fight_results_df, all_fight_stats_df = loop.run_until_complete(
    parse_fight_results_and_stats_async(list_of_fight_details_urls, config)
)

# Load existing fight results
existing_fight_results_file = config['fight_results_file_name']
if os.path.exists(existing_fight_results_file):
    existing_fight_results_df = pd.read_csv(existing_fight_results_file)
    existing_fight_results_urls = set(existing_fight_results_df['URL'])
else:
    existing_fight_results_df = pd.DataFrame(columns=all_fight_results_df.columns)
    existing_fight_results_urls = set()

# Identify new fight results
new_fight_results_df = all_fight_results_df[~all_fight_results_df['URL'].isin(existing_fight_results_urls)]

# Append new fight results to the dataset (newest first)
if not new_fight_results_df.empty:
    full_fight_results_df = pd.concat([new_fight_results_df, existing_fight_results_df], ignore_index=True)
    full_fight_results_df.to_csv(existing_fight_results_file, index=False)
else:
    full_fight_results_df = existing_fight_results_df

# **Always Display All Fight Results Data**
display(full_fight_results_df)

# Load existing fight stats
existing_fight_stats_file = config['fight_stats_file_name']
if os.path.exists(existing_fight_stats_file):
    existing_fight_stats_df = pd.read_csv(existing_fight_stats_file)
else:
    existing_fight_stats_df = pd.DataFrame(columns=all_fight_stats_df.columns)

# Append new fight stats to the dataset (newest first)
full_fight_stats_df = pd.concat([all_fight_stats_df, existing_fight_stats_df], ignore_index=True)
full_fight_stats_df.to_csv(existing_fight_stats_file, index=False)

# **Always Display All Fight Stats Data**
display(full_fight_stats_df)
# Out:
# Error fetching URL: http://ufcstats.com/fight-details/21f79cd40513d075, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/21f79cd40513d075, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/21f79cd40513d075, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/21f79cd40513d075, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/21f79cd40513d075, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/21f79cd40513d075, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/21f79cd40513d075, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/21f79cd40513d075, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/21f79cd40513d075, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/21f79cd40513d075
# Error fetching URL: http://ufcstats.com/fight-details/a457331c27bce6d5, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/a457331c27bce6d5, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/a457331c27bce6d5, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/a457331c27bce6d5, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/a457331c27bce6d5, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/a457331c27bce6d5, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/a457331c27bce6d5, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/a457331c27bce6d5, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/a457331c27bce6d5, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/a457331c27bce6d5
# Error fetching URL: http://ufcstats.com/fight-details/8cc43d79b61efc25, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/8cc43d79b61efc25, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/8cc43d79b61efc25, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/8cc43d79b61efc25, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/8cc43d79b61efc25, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/8cc43d79b61efc25, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/8cc43d79b61efc25, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/8cc43d79b61efc25, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/8cc43d79b61efc25, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/8cc43d79b61efc25
# Error fetching URL: http://ufcstats.com/fight-details/24a9fc95a3112f51, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/24a9fc95a3112f51, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/24a9fc95a3112f51, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/24a9fc95a3112f51, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/24a9fc95a3112f51, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/24a9fc95a3112f51, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/24a9fc95a3112f51, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/24a9fc95a3112f51, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/24a9fc95a3112f51, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/24a9fc95a3112f51
# Error fetching URL: http://ufcstats.com/fight-details/2c73bf152247f25a, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/2c73bf152247f25a, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/2c73bf152247f25a, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/2c73bf152247f25a, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/2c73bf152247f25a, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/2c73bf152247f25a, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/2c73bf152247f25a, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/2c73bf152247f25a, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/2c73bf152247f25a, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/2c73bf152247f25a
# Error fetching URL: http://ufcstats.com/fight-details/6e559181bfbc77e1, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/6e559181bfbc77e1, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/6e559181bfbc77e1, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/6e559181bfbc77e1, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/6e559181bfbc77e1, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/6e559181bfbc77e1, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/6e559181bfbc77e1, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/6e559181bfbc77e1, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/6e559181bfbc77e1, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/6e559181bfbc77e1
# Error fetching URL: http://ufcstats.com/fight-details/1bc662949337a8c4, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/1bc662949337a8c4, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/1bc662949337a8c4, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/1bc662949337a8c4, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/1bc662949337a8c4, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/1bc662949337a8c4, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/1bc662949337a8c4, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/1bc662949337a8c4, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/1bc662949337a8c4, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/1bc662949337a8c4
# Error fetching URL: http://ufcstats.com/fight-details/11e83902f5b8ff63, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/11e83902f5b8ff63, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/11e83902f5b8ff63, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/11e83902f5b8ff63, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/11e83902f5b8ff63, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/11e83902f5b8ff63, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/11e83902f5b8ff63, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/11e83902f5b8ff63, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/11e83902f5b8ff63, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/11e83902f5b8ff63
# Error fetching URL: http://ufcstats.com/fight-details/4e6218b6b892b017, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/4e6218b6b892b017, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/4e6218b6b892b017, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/4e6218b6b892b017, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/4e6218b6b892b017, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/4e6218b6b892b017, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/4e6218b6b892b017, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/4e6218b6b892b017, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/4e6218b6b892b017, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/4e6218b6b892b017
# Error fetching URL: http://ufcstats.com/fight-details/5095f6290670009d, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/5095f6290670009d, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/5095f6290670009d, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/5095f6290670009d, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/5095f6290670009d, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/5095f6290670009d, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/5095f6290670009d, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/5095f6290670009d, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/5095f6290670009d, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/5095f6290670009d
# Error fetching URL: http://ufcstats.com/fight-details/20cefe64f4b28be8, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/20cefe64f4b28be8, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/20cefe64f4b28be8, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/20cefe64f4b28be8, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/20cefe64f4b28be8, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/20cefe64f4b28be8, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/20cefe64f4b28be8, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/20cefe64f4b28be8, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/20cefe64f4b28be8, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/20cefe64f4b28be8
# Error fetching URL: http://ufcstats.com/fight-details/2c7c7648e847f2e5, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/2c7c7648e847f2e5, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/2c7c7648e847f2e5, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/2c7c7648e847f2e5, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/2c7c7648e847f2e5, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/2c7c7648e847f2e5, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/2c7c7648e847f2e5, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/2c7c7648e847f2e5, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/2c7c7648e847f2e5, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/2c7c7648e847f2e5
# Error fetching URL: http://ufcstats.com/fight-details/9a92d376fba2379d, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/9a92d376fba2379d, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/9a92d376fba2379d, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/9a92d376fba2379d, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/9a92d376fba2379d, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/9a92d376fba2379d, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/9a92d376fba2379d, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/9a92d376fba2379d, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/9a92d376fba2379d, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/9a92d376fba2379d
# Error fetching URL: http://ufcstats.com/fight-details/1378fc2be3819b2b, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/1378fc2be3819b2b, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/1378fc2be3819b2b, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/1378fc2be3819b2b, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/1378fc2be3819b2b, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/1378fc2be3819b2b, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/1378fc2be3819b2b, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/1378fc2be3819b2b, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/1378fc2be3819b2b, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/1378fc2be3819b2b
# Error fetching URL: http://ufcstats.com/fight-details/5b5d7f7ae712c6d8, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/5b5d7f7ae712c6d8, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/5b5d7f7ae712c6d8, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/5b5d7f7ae712c6d8, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/5b5d7f7ae712c6d8, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/5b5d7f7ae712c6d8, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/5b5d7f7ae712c6d8, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/5b5d7f7ae712c6d8, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/5b5d7f7ae712c6d8, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/5b5d7f7ae712c6d8
# Error fetching URL: http://ufcstats.com/fight-details/8b5c760f34daafe0, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/8b5c760f34daafe0, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/8b5c760f34daafe0, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/8b5c760f34daafe0, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/8b5c760f34daafe0, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/8b5c760f34daafe0, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/8b5c760f34daafe0, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/8b5c760f34daafe0, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/8b5c760f34daafe0, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/8b5c760f34daafe0
# Error fetching URL: http://ufcstats.com/fight-details/897d9e21c59d0633, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/897d9e21c59d0633, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/897d9e21c59d0633, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/897d9e21c59d0633, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/897d9e21c59d0633, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/897d9e21c59d0633, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/897d9e21c59d0633, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/897d9e21c59d0633, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/897d9e21c59d0633, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/897d9e21c59d0633
# Error fetching URL: http://ufcstats.com/fight-details/e8a5e53ffd33c0f9, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/e8a5e53ffd33c0f9, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/e8a5e53ffd33c0f9, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/e8a5e53ffd33c0f9, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/e8a5e53ffd33c0f9, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/e8a5e53ffd33c0f9, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/e8a5e53ffd33c0f9, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/e8a5e53ffd33c0f9, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/e8a5e53ffd33c0f9, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/e8a5e53ffd33c0f9
# Error fetching URL: http://ufcstats.com/fight-details/fd49f89b9d97566b, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/fd49f89b9d97566b, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/fd49f89b9d97566b, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/fd49f89b9d97566b, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/fd49f89b9d97566b, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/fd49f89b9d97566b, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/fd49f89b9d97566b, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/fd49f89b9d97566b, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/fd49f89b9d97566b, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/fd49f89b9d97566b
# Error fetching URL: http://ufcstats.com/fight-details/049ad6d87b42eba8, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/049ad6d87b42eba8, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/049ad6d87b42eba8, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/049ad6d87b42eba8, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/049ad6d87b42eba8, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/049ad6d87b42eba8, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/049ad6d87b42eba8, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/049ad6d87b42eba8, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/049ad6d87b42eba8, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/049ad6d87b42eba8
# Error fetching URL: http://ufcstats.com/fight-details/4305cb30533dac77, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/4305cb30533dac77, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/4305cb30533dac77, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/4305cb30533dac77, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/4305cb30533dac77, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/4305cb30533dac77, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/4305cb30533dac77, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/4305cb30533dac77, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/4305cb30533dac77, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/4305cb30533dac77
# Error fetching URL: http://ufcstats.com/fight-details/d7a7ba46c4f075d7, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/d7a7ba46c4f075d7, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/d7a7ba46c4f075d7, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/d7a7ba46c4f075d7, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/d7a7ba46c4f075d7, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/d7a7ba46c4f075d7, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/d7a7ba46c4f075d7, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/d7a7ba46c4f075d7, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/d7a7ba46c4f075d7, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/d7a7ba46c4f075d7
# Error fetching URL: http://ufcstats.com/fight-details/f115a91066a77ee7, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/f115a91066a77ee7, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/f115a91066a77ee7, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/f115a91066a77ee7, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/f115a91066a77ee7, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/f115a91066a77ee7, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/f115a91066a77ee7, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/f115a91066a77ee7, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/f115a91066a77ee7, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/f115a91066a77ee7
# Error fetching URL: http://ufcstats.com/fight-details/c94b153951be7590, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/c94b153951be7590, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/c94b153951be7590, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/c94b153951be7590, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/c94b153951be7590, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/c94b153951be7590, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/c94b153951be7590, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/c94b153951be7590, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/c94b153951be7590, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/c94b153951be7590
# Error fetching URL: http://ufcstats.com/fight-details/4a116a55ffaa0d64, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/4a116a55ffaa0d64, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/4a116a55ffaa0d64, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/4a116a55ffaa0d64, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/4a116a55ffaa0d64, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/4a116a55ffaa0d64, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/4a116a55ffaa0d64, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/4a116a55ffaa0d64, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/4a116a55ffaa0d64, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/4a116a55ffaa0d64
# Error fetching URL: http://ufcstats.com/fight-details/50eed57ea1390e16, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/50eed57ea1390e16, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/50eed57ea1390e16, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/50eed57ea1390e16, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/50eed57ea1390e16, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/50eed57ea1390e16, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/50eed57ea1390e16, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/50eed57ea1390e16, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/50eed57ea1390e16, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/50eed57ea1390e16
# Error fetching URL: http://ufcstats.com/fight-details/029f5c36820fdc09, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/029f5c36820fdc09, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/029f5c36820fdc09, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/029f5c36820fdc09, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/029f5c36820fdc09, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/029f5c36820fdc09, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/029f5c36820fdc09, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/029f5c36820fdc09, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/029f5c36820fdc09, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/029f5c36820fdc09
# Error fetching URL: http://ufcstats.com/fight-details/f466cd99d02644e9, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/f466cd99d02644e9, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/f466cd99d02644e9, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/f466cd99d02644e9, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/f466cd99d02644e9, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/f466cd99d02644e9, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/f466cd99d02644e9, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/f466cd99d02644e9, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/f466cd99d02644e9, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/f466cd99d02644e9
# Error fetching URL: http://ufcstats.com/fight-details/5f4a107d930e4852, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/5f4a107d930e4852, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/5f4a107d930e4852, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/5f4a107d930e4852, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/5f4a107d930e4852, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/5f4a107d930e4852, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/5f4a107d930e4852, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/5f4a107d930e4852, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/5f4a107d930e4852, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/5f4a107d930e4852
# Error fetching URL: http://ufcstats.com/fight-details/7a635063e5f1699b, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/7a635063e5f1699b, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/7a635063e5f1699b, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/7a635063e5f1699b, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/7a635063e5f1699b, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/7a635063e5f1699b, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/7a635063e5f1699b, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/7a635063e5f1699b, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/7a635063e5f1699b, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/7a635063e5f1699b
# Error fetching URL: http://ufcstats.com/fight-details/aacb47949a572f25, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/aacb47949a572f25, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/aacb47949a572f25, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/aacb47949a572f25, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/aacb47949a572f25, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/aacb47949a572f25, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/aacb47949a572f25, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/aacb47949a572f25, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/aacb47949a572f25, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/aacb47949a572f25
# Error fetching URL: http://ufcstats.com/fight-details/344d60564cd136ff, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/344d60564cd136ff, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/344d60564cd136ff, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/344d60564cd136ff, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/344d60564cd136ff, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/344d60564cd136ff, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/344d60564cd136ff, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/344d60564cd136ff, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/344d60564cd136ff, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/344d60564cd136ff
# Error fetching URL: http://ufcstats.com/fight-details/3aa49ed298e4c34f, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/3aa49ed298e4c34f, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/3aa49ed298e4c34f, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/3aa49ed298e4c34f, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/3aa49ed298e4c34f, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/3aa49ed298e4c34f, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/3aa49ed298e4c34f, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/3aa49ed298e4c34f, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/3aa49ed298e4c34f, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/3aa49ed298e4c34f
# Error fetching URL: http://ufcstats.com/fight-details/a679800d2e7c3be2, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/a679800d2e7c3be2, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/a679800d2e7c3be2, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/a679800d2e7c3be2, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/a679800d2e7c3be2, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/a679800d2e7c3be2, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/a679800d2e7c3be2, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/a679800d2e7c3be2, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/a679800d2e7c3be2, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/a679800d2e7c3be2
# Error fetching URL: http://ufcstats.com/fight-details/93969a7368dc2e14, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/93969a7368dc2e14, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/93969a7368dc2e14, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/93969a7368dc2e14, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/93969a7368dc2e14, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/93969a7368dc2e14, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/93969a7368dc2e14, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/93969a7368dc2e14, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/93969a7368dc2e14, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/93969a7368dc2e14
# Error fetching URL: http://ufcstats.com/fight-details/4f2501e804c84abe, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/4f2501e804c84abe, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/4f2501e804c84abe, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/4f2501e804c84abe, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/4f2501e804c84abe, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/4f2501e804c84abe, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/4f2501e804c84abe, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/4f2501e804c84abe, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/4f2501e804c84abe, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/4f2501e804c84abe
# Error fetching URL: http://ufcstats.com/fight-details/e5e75d831670b401, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/e5e75d831670b401, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/e5e75d831670b401, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/e5e75d831670b401, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/e5e75d831670b401, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/e5e75d831670b401, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/e5e75d831670b401, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/e5e75d831670b401, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/e5e75d831670b401, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/e5e75d831670b401
# Error fetching URL: http://ufcstats.com/fight-details/04e6198326be4857, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/04e6198326be4857, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/04e6198326be4857, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/04e6198326be4857, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/04e6198326be4857, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/04e6198326be4857, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/04e6198326be4857, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/04e6198326be4857, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/04e6198326be4857, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/04e6198326be4857
# Error fetching URL: http://ufcstats.com/fight-details/ed32da52aff68944, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/ed32da52aff68944, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/ed32da52aff68944, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/ed32da52aff68944, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/ed32da52aff68944, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/ed32da52aff68944, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/ed32da52aff68944, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/ed32da52aff68944, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/ed32da52aff68944, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/ed32da52aff68944
# Error fetching URL: http://ufcstats.com/fight-details/43d7d4b67be48553, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/43d7d4b67be48553, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/43d7d4b67be48553, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/43d7d4b67be48553, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/43d7d4b67be48553, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/43d7d4b67be48553, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/43d7d4b67be48553, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/43d7d4b67be48553, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/43d7d4b67be48553, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/43d7d4b67be48553
# Error fetching URL: http://ufcstats.com/fight-details/7e20b0536fbbd560, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/7e20b0536fbbd560, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/7e20b0536fbbd560, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/7e20b0536fbbd560, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/7e20b0536fbbd560, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/7e20b0536fbbd560, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/7e20b0536fbbd560, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/7e20b0536fbbd560, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/7e20b0536fbbd560, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/7e20b0536fbbd560
# Error fetching URL: http://ufcstats.com/fight-details/a09447d185a62251, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/a09447d185a62251, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/a09447d185a62251, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/a09447d185a62251, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/a09447d185a62251, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/a09447d185a62251, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/a09447d185a62251, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/a09447d185a62251, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/a09447d185a62251, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/a09447d185a62251
# Error fetching URL: http://ufcstats.com/fight-details/59b2bbb251968ca9, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/59b2bbb251968ca9, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/59b2bbb251968ca9, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/59b2bbb251968ca9, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/59b2bbb251968ca9, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/59b2bbb251968ca9, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/59b2bbb251968ca9, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/59b2bbb251968ca9, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/59b2bbb251968ca9, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/59b2bbb251968ca9
# Error fetching URL: http://ufcstats.com/fight-details/7a2c841693b54dd7, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/7a2c841693b54dd7, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/7a2c841693b54dd7, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/7a2c841693b54dd7, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/7a2c841693b54dd7, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/7a2c841693b54dd7, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/7a2c841693b54dd7, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/7a2c841693b54dd7, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/7a2c841693b54dd7, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/7a2c841693b54dd7
# Error fetching URL: http://ufcstats.com/fight-details/5d4fb748ad246269, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/5d4fb748ad246269, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/5d4fb748ad246269, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/5d4fb748ad246269, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/5d4fb748ad246269, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/5d4fb748ad246269, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/5d4fb748ad246269, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/5d4fb748ad246269, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/5d4fb748ad246269, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/5d4fb748ad246269
# Error fetching URL: http://ufcstats.com/fight-details/f682118709b4143e, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/f682118709b4143e, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/f682118709b4143e, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/f682118709b4143e, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/f682118709b4143e, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/f682118709b4143e, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/f682118709b4143e, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/f682118709b4143e, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/f682118709b4143e, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/f682118709b4143e
# Error fetching URL: http://ufcstats.com/fight-details/5eaff5c832430378, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/5eaff5c832430378, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/5eaff5c832430378, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/5eaff5c832430378, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/5eaff5c832430378, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/5eaff5c832430378, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/5eaff5c832430378, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/5eaff5c832430378, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/5eaff5c832430378, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/5eaff5c832430378
# Error fetching URL: http://ufcstats.com/fight-details/4a789cdd5aaf4439, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/4a789cdd5aaf4439, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/4a789cdd5aaf4439, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/4a789cdd5aaf4439, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/4a789cdd5aaf4439, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/4a789cdd5aaf4439, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/4a789cdd5aaf4439, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/4a789cdd5aaf4439, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/4a789cdd5aaf4439, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/4a789cdd5aaf4439
# Error fetching URL: http://ufcstats.com/fight-details/cbdfb3c648d7bada, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/cbdfb3c648d7bada, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/cbdfb3c648d7bada, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/cbdfb3c648d7bada, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/cbdfb3c648d7bada, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/cbdfb3c648d7bada, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/cbdfb3c648d7bada, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/cbdfb3c648d7bada, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/cbdfb3c648d7bada, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/cbdfb3c648d7bada
# Error fetching URL: http://ufcstats.com/fight-details/1b4d0c9e3c59b33b, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/1b4d0c9e3c59b33b, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/1b4d0c9e3c59b33b, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/1b4d0c9e3c59b33b, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/1b4d0c9e3c59b33b, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/1b4d0c9e3c59b33b, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/1b4d0c9e3c59b33b, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/1b4d0c9e3c59b33b, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/1b4d0c9e3c59b33b, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/1b4d0c9e3c59b33b
# Error fetching URL: http://ufcstats.com/fight-details/534c07488396e124, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/534c07488396e124, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/534c07488396e124, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/534c07488396e124, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/534c07488396e124, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/534c07488396e124, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/534c07488396e124, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/534c07488396e124, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/534c07488396e124, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/534c07488396e124
# Error fetching URL: http://ufcstats.com/fight-details/3542f9f30926f364, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/3542f9f30926f364, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/3542f9f30926f364, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/3542f9f30926f364, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/3542f9f30926f364, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/3542f9f30926f364, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/3542f9f30926f364, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/3542f9f30926f364, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/3542f9f30926f364, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/3542f9f30926f364
# Error fetching URL: http://ufcstats.com/fight-details/5136dc566f46daf6, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/5136dc566f46daf6, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/5136dc566f46daf6, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/5136dc566f46daf6, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/5136dc566f46daf6, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/5136dc566f46daf6, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/5136dc566f46daf6, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/5136dc566f46daf6, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/5136dc566f46daf6, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/5136dc566f46daf6
# Error fetching URL: http://ufcstats.com/fight-details/bc7228d30ff5be46, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/bc7228d30ff5be46, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/bc7228d30ff5be46, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/bc7228d30ff5be46, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/bc7228d30ff5be46, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/bc7228d30ff5be46, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/bc7228d30ff5be46, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/bc7228d30ff5be46, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/bc7228d30ff5be46, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/bc7228d30ff5be46
# Error fetching URL: http://ufcstats.com/fight-details/5c281439d20184f1, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/5c281439d20184f1, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/5c281439d20184f1, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/5c281439d20184f1, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/5c281439d20184f1, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/5c281439d20184f1, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/5c281439d20184f1, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/5c281439d20184f1, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/5c281439d20184f1, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/5c281439d20184f1
# Error fetching URL: http://ufcstats.com/fight-details/2fa88b72973478b6, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/2fa88b72973478b6, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/2fa88b72973478b6, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/2fa88b72973478b6, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/2fa88b72973478b6, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/2fa88b72973478b6, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/2fa88b72973478b6, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/2fa88b72973478b6, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/2fa88b72973478b6, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/2fa88b72973478b6
# Error fetching URL: http://ufcstats.com/fight-details/43543a2c1c7a7135, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/43543a2c1c7a7135, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/43543a2c1c7a7135, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/43543a2c1c7a7135, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/43543a2c1c7a7135, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/43543a2c1c7a7135, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/43543a2c1c7a7135, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/43543a2c1c7a7135, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/43543a2c1c7a7135, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/43543a2c1c7a7135
# Error fetching URL: http://ufcstats.com/fight-details/fad150a0288efbd7, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/fad150a0288efbd7, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/fad150a0288efbd7, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/fad150a0288efbd7, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/fad150a0288efbd7, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/fad150a0288efbd7, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/fad150a0288efbd7, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/fad150a0288efbd7, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/fad150a0288efbd7, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/fad150a0288efbd7
# Error fetching URL: http://ufcstats.com/fight-details/e240d6f77747ec46, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/e240d6f77747ec46, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/e240d6f77747ec46, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/e240d6f77747ec46, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/e240d6f77747ec46, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/e240d6f77747ec46, attempt 3
# ...
# Error fetching URL: http://ufcstats.com/fight-details/62f487635d7a9bb0, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/62f487635d7a9bb0, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/62f487635d7a9bb0, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/62f487635d7a9bb0, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/62f487635d7a9bb0, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/62f487635d7a9bb0, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/62f487635d7a9bb0, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/62f487635d7a9bb0
# Error fetching URL: http://ufcstats.com/fight-details/8d26509990b6e518, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/8d26509990b6e518, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/8d26509990b6e518, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/8d26509990b6e518, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/8d26509990b6e518, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/8d26509990b6e518, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/8d26509990b6e518, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/8d26509990b6e518, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/8d26509990b6e518, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/8d26509990b6e518
# Error fetching URL: http://ufcstats.com/fight-details/ae674ec42bd0a979, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/ae674ec42bd0a979, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/ae674ec42bd0a979, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/ae674ec42bd0a979, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/ae674ec42bd0a979, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/ae674ec42bd0a979, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/ae674ec42bd0a979, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/ae674ec42bd0a979, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/ae674ec42bd0a979, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/ae674ec42bd0a979
# Error fetching URL: http://ufcstats.com/fight-details/6760e48a36571feb, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/6760e48a36571feb, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/6760e48a36571feb, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/6760e48a36571feb, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/6760e48a36571feb, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/6760e48a36571feb, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/6760e48a36571feb, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/6760e48a36571feb, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/6760e48a36571feb, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/6760e48a36571feb
# Error fetching URL: http://ufcstats.com/fight-details/51b0cc51799e7d5d, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/51b0cc51799e7d5d, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/51b0cc51799e7d5d, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/51b0cc51799e7d5d, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/51b0cc51799e7d5d, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/51b0cc51799e7d5d, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/51b0cc51799e7d5d, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/51b0cc51799e7d5d, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/51b0cc51799e7d5d, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/51b0cc51799e7d5d
# Error fetching URL: http://ufcstats.com/fight-details/ac82d28aaa5faaf0, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/ac82d28aaa5faaf0, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/ac82d28aaa5faaf0, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/ac82d28aaa5faaf0, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/ac82d28aaa5faaf0, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/ac82d28aaa5faaf0, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/ac82d28aaa5faaf0, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/ac82d28aaa5faaf0, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/ac82d28aaa5faaf0, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/ac82d28aaa5faaf0
# Error fetching URL: http://ufcstats.com/fight-details/61f0ceb980c1ae81, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/61f0ceb980c1ae81, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/61f0ceb980c1ae81, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/61f0ceb980c1ae81, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/61f0ceb980c1ae81, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/61f0ceb980c1ae81, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/61f0ceb980c1ae81, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/61f0ceb980c1ae81, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/61f0ceb980c1ae81, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/61f0ceb980c1ae81
# Error fetching URL: http://ufcstats.com/fight-details/bbe3d2a2ad8d204e, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/bbe3d2a2ad8d204e, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/bbe3d2a2ad8d204e, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/bbe3d2a2ad8d204e, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/bbe3d2a2ad8d204e, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/bbe3d2a2ad8d204e, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/bbe3d2a2ad8d204e, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/bbe3d2a2ad8d204e, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/bbe3d2a2ad8d204e, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/bbe3d2a2ad8d204e
# Error fetching URL: http://ufcstats.com/fight-details/66f0238fac31130f, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/66f0238fac31130f, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/66f0238fac31130f, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/66f0238fac31130f, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/66f0238fac31130f, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/66f0238fac31130f, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/66f0238fac31130f, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/66f0238fac31130f, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/66f0238fac31130f, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/66f0238fac31130f
# Error fetching URL: http://ufcstats.com/fight-details/13858ffdaaef5671, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/13858ffdaaef5671, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/13858ffdaaef5671, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/13858ffdaaef5671, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/13858ffdaaef5671, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/13858ffdaaef5671, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/13858ffdaaef5671, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/13858ffdaaef5671, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/13858ffdaaef5671, attempt 3
# ❌ Failed to fetch event page: http://ufcstats.com/fight-details/13858ffdaaef5671
# Error fetching URL: http://ufcstats.com/fight-details/bcefcb29bec709d6, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/bcefcb29bec709d6, attempt 2
# Error fetching URL: http://ufcstats.com/fight-details/bcefcb29bec709d6, attempt 3
# Error fetching URL: http://ufcstats.com/fight-details/bcefcb29bec709d6, attempt 1
# Error fetching URL: http://ufcstats.com/fight-details/bcefcb29bec709d6, attempt 2
#                                       EVENT  \
# 0     UFC Fight Night: Adesanya vs. Imavov
# 1     UFC Fight Night: Adesanya vs. Imavov
# 2     UFC Fight Night: Adesanya vs. Imavov
# 3     UFC Fight Night: Adesanya vs. Imavov
# 4     UFC Fight Night: Adesanya vs. Imavov
# ...                                     ...
# 7419                 UFC - Ultimate Brazil
# 7420                 UFC - Ultimate Brazil
# 7421                 UFC - Ultimate Brazil
# 7422                  UFC - Ultimate Japan
# 7423                  UFC - Ultimate Japan
#
#                                               BOUT OUTCOME  \
# 0         Israel Adesanya  vs. Nassourdine Imavov      L/W
# 1               Shara Magomedov  vs. Michael Page      L/W
# 2     Sergei Pavlovich  vs. Jairzinho Rozenstruik      W/L
# 3        Said Nurmagomedov  vs. Vinicius Oliveira      L/W
# 4                      Fares Ziam  vs. Mike Davis      W/L
# ...                                            ...     ...
# 7419          Tsuyoshi Kohsaka  vs. Pete Williams      W/L
# 7420       Ebenezer Fontes Braga  vs. Jeremy Horn      W/L
# 7421           Tulio Palhares  vs. Adriano Santos      W/L
# 7422        Kazushi Sakuraba  vs. Marcus Silveira      W/L
# 7423               Vitor Belfort  vs. Joe Charles      W/L
#
#                                            WEIGHTCLASS                 METHOD  \
# 0                                    Middleweight Bout                KO/TKO
# 1                                    Middleweight Bout  Decision - Unanimous
# 2                                     Heavyweight Bout  Decision - Unanimous
# 3                                    Bantamweight Bout  Decision - Unanimous
# 4                                     Lightweight Bout  Decision - Unanimous
# ...                                                ...                    ...
# 7419                                  Heavyweight Bout  Decision - Unanimous
# 7420                                 Middleweight Bout            Submission
# 7421                                 Middleweight Bout                KO/TKO
# 7422  Ultimate Japan Heavyweight Tournament Title Bout            Submission
# 7423                                  Heavyweight Bout            Submission
#
#      ROUND  TIME        TIME FORMAT        REFEREE  \
# 0        2  0:30  5 Rnd (5-5-5-5-5)   Marc Goddard
# 1        3  5:00      3 Rnd (5-5-5)   Jason Herzog
# 2        3  5:00      3 Rnd (5-5-5)     Mark Smith
# 3        3  5:00      3 Rnd (5-5-5)   Kerry Hatley
# 4        3  5:00      3 Rnd (5-5-5)  Chris Tognoni
# ...    ...   ...                ...            ...
# 7419     2  3:00  1 Rnd + OT (12-3)  John McCarthy
# 7420     1  3:27  1 Rnd + OT (12-3)  John McCarthy
# 7421     1  9:00  1 Rnd + OT (12-3)  John McCarthy
# 7422     1  3:44  1 Rnd + OT (12-3)  John McCarthy
# 7423     1  4:03  1 Rnd + OT (12-3)  John McCarthy
#
#                                                 DETAILS  \
# 0                            Punch to Head At Distance
# 1     Jacob Montalvo 27 - 30.Clemens Werner 27 - 30....
# 2     Sal D'amato 27 - 30.David Lethaby 27 - 30.Clem...
# 3     Ben Cartlidge 28 - 29.Jacob Montalvo 28 - 29.T...
# 4     Sal D'amato 27 - 30.David Lethaby 27 - 30.Clem...
# ...                                                 ...
# 7419                                                NaN
# 7420                         Guillotine Choke Standing
# 7421                        Punches to Head From Mount
# 7422                          Armbar From Side Control
# 7423                                 Armbar From Mount
#
#                                                     URL
# 0     http://ufcstats.com/fight-details/85e79748b75e...
# 1     http://ufcstats.com/fight-details/426e7a3de681...
# 2     http://ufcstats.com/fight-details/3c00f34f20c8...
# 3     http://ufcstats.com/fight-details/70b8dca3addc...
# 4     http://ufcstats.com/fight-details/775788423f5e...
# ...                                                 ...
# 7419  http://ufcstats.com/fight-details/dbdad3eb1577...
# 7420  http://ufcstats.com/fight-details/b6de61e312db...
# 7421  http://ufcstats.com/fight-details/35b871e0bdc1...
# 7422  http://ufcstats.com/fight-details/ec1bda9a4c2a...
# 7423  http://ufcstats.com/fight-details/5c3542260741...
#
# [7424 rows x 11 columns]
#                                       EVENT  \
# 0      UFC Fight Night: Adesanya vs. Imavov
# 1      UFC Fight Night: Adesanya vs. Imavov
# 2      UFC Fight Night: Adesanya vs. Imavov
# 3      UFC Fight Night: Adesanya vs. Imavov
# 4      UFC Fight Night: Adesanya vs. Imavov
# ...                                     ...
# 35137                 UFC - Ultimate Brazil
# 35138                  UFC - Ultimate Japan
# 35139                  UFC - Ultimate Japan
# 35140                  UFC - Ultimate Japan
# 35141                  UFC - Ultimate Japan
#
#                                          BOUT    ROUND             FIGHTER KD  \
# 0      Israel Adesanya vs. Nassourdine Imavov  Round 1     Israel Adesanya  0
# 1      Israel Adesanya vs. Nassourdine Imavov  Round 2     Israel Adesanya  0
# 2      Israel Adesanya vs. Nassourdine Imavov  Round 1  Nassourdine Imavov  0
# 3      Israel Adesanya vs. Nassourdine Imavov  Round 2  Nassourdine Imavov  1
# 4            Shara Magomedov vs. Michael Page  Round 1     Shara Magomedov  0
# ...                                       ...      ...                 ... ..
# 35137       Tulio Palhares vs. Adriano Santos  Round 1      Adriano Santos  0
# 35138    Kazushi Sakuraba vs. Marcus Silveira  Round 1    Kazushi Sakuraba  0
# 35139    Kazushi Sakuraba vs. Marcus Silveira  Round 1     Marcus Silveira  0
# 35140           Vitor Belfort vs. Joe Charles  Round 1       Vitor Belfort  0
# 35141           Vitor Belfort vs. Joe Charles  Round 1         Joe Charles  0
#
#        SIG.STR. SIG.STR. % TOTAL STR.      TD  TD % SUB.ATT REV.  CTRL  \
# 0      20 of 44        45%   26 of 50  0 of 1    0%       0    0  0:00
# 1        6 of 6       100%     6 of 6  0 of 0   ---       0    0  0:00
# 2       8 of 21        38%   10 of 23  0 of 3    0%       0    0  0:40
# 3       7 of 10        70%    8 of 11  0 of 0   ---       0    0  0:04
# 4       9 of 25        36%    9 of 25  0 of 0   ---       0    0  0:00
# ...         ...        ...        ...     ...   ...     ...  ...   ...
# 35137  11 of 36        30%   21 of 47  2 of 3   66%       0    1    --
# 35138    1 of 2        50%     2 of 3  1 of 1  100%       2    0    --
# 35139    1 of 2        50%   11 of 13  1 of 1  100%       1    0    --
# 35140    0 of 0        ---     0 of 0  2 of 2  100%       3    0    --
# 35141    1 of 1       100%     1 of 1  0 of 0   ---       0    1    --
#
#           HEAD    BODY      LEG  DISTANCE  CLINCH   GROUND
# 0      8 of 27  3 of 5  9 of 12  20 of 44  0 of 0   0 of 0
# 1       1 of 1  3 of 3   2 of 2    6 of 6  0 of 0   0 of 0
# 2      3 of 13  0 of 2   5 of 6   8 of 21  0 of 0   0 of 0
# 3       6 of 8  0 of 1   1 of 1    2 of 4  0 of 0   5 of 6
# 4      1 of 10  2 of 3  6 of 12   9 of 24  0 of 1   0 of 0
# ...        ...     ...      ...       ...     ...      ...
# 35137  8 of 30  2 of 3   1 of 3   4 of 24  0 of 0  7 of 12
# 35138   1 of 2  0 of 0   0 of 0    0 of 1  0 of 0   1 of 1
# 35139   1 of 2  0 of 0   0 of 0    0 of 1  1 of 1   0 of 0
# 35140   0 of 0  0 of 0   0 of 0    0 of 0  0 of 0   0 of 0
# 35141   0 of 0  0 of 0   1 of 1    1 of 1  0 of 0   0 of 0
#
# [35142 rows x 19 columns]

# %%
# Ensure "data" folder exists
os.makedirs("data", exist_ok=True)

# Define paths for saving all CSVs
#fight_events_path = os.path.join("data", config['fight_event_file_name'])
fight_details_path = os.path.join("data", config['fight_details_file_name'])
fight_results_path = os.path.join("data", config['fight_results_file_name'])
fight_stats_path = os.path.join("data", config['fight_stats_file_name'])

# Save fight details
full_fight_details_df.to_csv(fight_details_path, index=False)
print(f"📁 Saved fight details to {fight_details_path}")

# Save fight results
full_fight_results_df.to_csv(fight_results_path, index=False)
print(f"📁 Saved fight results to {fight_results_path}")

# Save fight stats
full_fight_stats_df.to_csv(fight_stats_path, index=False)
print(f"📁 Saved fight stats to {fight_stats_path}")
# Out:
# 📁 Saved fight details to data\ufc_fight_details.csv
# 📁 Saved fight results to data\ufc_fight_results.csv
# 📁 Saved fight stats to data\ufc_fight_stats.csv
