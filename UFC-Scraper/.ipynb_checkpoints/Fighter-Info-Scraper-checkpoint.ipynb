# %%
pip install fuzzywuzzy[speedup]
# Out:
# Requirement already satisfied: fuzzywuzzy[speedup] in c:\users\cadeb\anaconda3\lib\site-packages (0.18.0)
# Requirement already satisfied: python-levenshtein>=0.12 in c:\users\cadeb\anaconda3\lib\site-packages (from fuzzywuzzy[speedup]) (0.26.1)
# Requirement already satisfied: Levenshtein==0.26.1 in c:\users\cadeb\anaconda3\lib\site-packages (from python-levenshtein>=0.12->fuzzywuzzy[speedup]) (0.26.1)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.9.0 in c:\users\cadeb\anaconda3\lib\site-packages (from Levenshtein==0.26.1->python-levenshtein>=0.12->fuzzywuzzy[speedup]) (3.11.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import logging
from tqdm.notebook import tqdm_notebook
from fuzzywuzzy import fuzz
import random
import yaml

# %%
# Logging setup
logging.basicConfig(level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s")

# Load configuration
config = {
    "headers": {"User-Agent": "Mozilla/5.0 (Windows NT 10.0)"},
    "retries": 3,
    "sleep_range": [1, 3],
}

# %%
# Normalize fighter names for URL generation
def normalize_name(fighter_name):
    return fighter_name.lower().replace(" ", "-")

# %%
# Randomized sleep to mimic human behavior
def random_sleep():
    time.sleep(random.uniform(*config["sleep_range"]))

# %%
# Fetch URL with retry logic and exponential backoff
def fetch_with_retry(url, max_retries=config["retries"]):
    for i in range(max_retries):
        try:
            response = requests.get(url, headers=config["headers"], timeout=10)
            if response.status_code == 200:
                return response
        except requests.RequestException as e:
            logging.warning(f"Retrying ({i + 1}/{max_retries}) for {url}: {e}")
        time.sleep(2 ** i)  # Exponential backoff
    logging.error(f"Failed to fetch {url} after {max_retries} retries")
    return None

# %%
# Normalize and validate data
def normalize_height(height):
    if height and "'" in height:
        return height.replace('"', "\"")  # Escape double quotes for consistency
    return height

# %%
# Function to find UFC Stats URL for a fighter
def find_ufcstats_url(fighter_name):
    base_url = "http://ufcstats.com/statistics/fighters?char=a&page=all"
    response = fetch_with_retry(base_url)
    if not response:
        logging.warning(f"Failed to fetch UFC Stats directory for {fighter_name}")
        return None

    soup = BeautifulSoup(response.text, "html.parser")
    fighters = soup.find_all("a", class_="b-link b-link_style_black")

    best_match = None
    best_score = 0

    for fighter in fighters:
        match_score = fuzz.partial_ratio(fighter_name.lower(), fighter.text.lower())
        if match_score > best_score and match_score > 80:  # Threshold for matching
            best_match = fighter["href"]
            best_score = match_score

    if best_match:
        logging.info(f"Found UFC Stats URL for {fighter_name}: {best_match}")
        return best_match
    
    logging.warning(f"Could not find UFC Stats URL for {fighter_name}")
    return None

# %%
# Function to find Tapology URL for a fighter
def find_tapology_url(fighter_name):
    search_url = f"https://www.tapology.com/search/mma-fighters/{fighter_name.replace(' ', '%20')}"
    response = fetch_with_retry(search_url)
    if not response:
        logging.warning(f"Failed to fetch Tapology search results for {fighter_name}")
        return None

    soup = BeautifulSoup(response.text, "html.parser")
    search_results = soup.find_all("a", class_="search-result-link")

    best_match = None
    best_score = 0

    for result in search_results:
        name = result.find("h4").text.strip() if result.find("h4") else ""
        match_score = fuzz.partial_ratio(fighter_name.lower(), name.lower())
        if match_score > best_score and match_score > 80:  # Threshold for matching
            best_match = "https://www.tapology.com" + result["href"]
            best_score = match_score

    if best_match:
        logging.info(f"Found Tapology URL for {fighter_name}: {best_match}")
        return best_match
    
    logging.warning(f"Could not find Tapology URL for {fighter_name}")
    return None

# %%
# Function to find MMA Decisions URL for a fighter
def find_mmadecisions_url(fighter_name):
    search_url = f"https://mmadecisions.com/search.php?search_query={fighter_name.replace(' ', '+')}"
    response = fetch_with_retry(search_url)
    if not response:
        logging.warning(f"Failed to fetch MMA Decisions search results for {fighter_name}")
        return None

    soup = BeautifulSoup(response.text, "html.parser")
    search_results = soup.find_all("a", href=True)

    best_match = None
    best_score = 0

    for result in search_results:
        if "/fighter/" in result["href"]:
            name = result.text.strip()
            match_score = fuzz.partial_ratio(fighter_name.lower(), name.lower())
            if match_score > best_score and match_score > 80:  # Threshold for matching
                best_match = "https://mmadecisions.com" + result["href"]
                best_score = match_score

    if best_match:
        logging.info(f"Found MMA Decisions URL for {fighter_name}: {best_match}")
        return best_match
    
    logging.warning(f"Could not find MMA Decisions URL for {fighter_name}")
    return None

# %%
# Scrape details from UFC Stats
def scrape_ufcstats_details(url):
    response = fetch_with_retry(url)
    if not response:
        return {}
    
    soup = BeautifulSoup(response.text, "html.parser")
    details = {}

    try:
        details["HEIGHT"] = normalize_height(soup.find(string="Height:").find_next("td").string.strip())
        details["WEIGHT"] = soup.find(string="Weight:").find_next("td").string.strip()
        details["REACH"] = soup.find(string="Reach:").find_next("td").string.strip()
        details["STANCE"] = soup.find(string="Stance:").find_next("td").string.strip()
        details["DOB"] = soup.find(string="DOB:").find_next("td").string.strip()
    except AttributeError:
        logging.warning(f"Some details missing for UFC Stats: {url}")

    return details

# %%
# Scrape details from Tapology
def scrape_tapology_details(url):
    response = fetch_with_retry(url)
    if not response:
        return {}

    soup = BeautifulSoup(response.text, "html.parser")
    details = {}

    try:
        details["HEIGHT"] = normalize_height(soup.find(string="Height:").find_next("td").string.strip())
        details["WEIGHT"] = soup.find(string="Weight:").find_next("td").string.strip()
        details["REACH"] = soup.find(string="Reach:").find_next("td").string.strip()
        details["STANCE"] = soup.find(string="Stance:").find_next("td").string.strip()
        details["DOB"] = soup.find(string="DOB:").find_next("td").string.strip()
    except AttributeError:
        logging.warning(f"Some details missing for Tapology: {url}")

    return details

# %%
# Scrape details from MMA Decisions
def scrape_mmadecisions_details(url):
    response = fetch_with_retry(url)
    if not response:
        return {}

    soup = BeautifulSoup(response.text, "html.parser")
    details = {}

    try:
        details["HEIGHT"] = normalize_height(soup.find(string="Height:").find_next("td").string.strip())
        details["WEIGHT"] = soup.find(string="Weight:").find_next("td").string.strip()
        details["REACH"] = soup.find(string="Reach:").find_next("td").string.strip()
        details["STANCE"] = soup.find(string="Stance:").find_next("td").string.strip()
        details["DOB"] = soup.find(string="DOB:").find_next("td").string.strip()
    except AttributeError:
        logging.warning(f"Some details missing for MMA Decisions: {url}")

    return details

# %%
# Aggregate details from all sources
def aggregate_fighter_details(fighter_name):
    final_details = {"FIGHTER": fighter_name}

    # Find UFC Stats URL
    ufc_url = find_ufcstats_url(fighter_name)
    final_details["UFC_URL"] = ufc_url

    # Scrape UFC Stats first
    if ufc_url:
        final_details.update(scrape_ufcstats_details(ufc_url))

    # Find Tapology URL
    tapology_url = find_tapology_url(fighter_name)
    final_details["TAPOLOGY_URL"] = tapology_url

    # Scrape Tapology if UFC Stats is incomplete
    if tapology_url and any(not final_details.get(col) for col in ["HEIGHT", "WEIGHT", "REACH", "STANCE", "DOB"]):
        final_details.update(scrape_tapology_details(tapology_url))

    # Find MMA Decisions URL
    mmadecisions_url = find_mmadecisions_url(fighter_name)
    final_details["MMADECISIONS_URL"] = mmadecisions_url

    # Scrape MMA Decisions if data is still incomplete
    if mmadecisions_url and any(not final_details.get(col) for col in ["HEIGHT", "WEIGHT", "REACH", "STANCE", "DOB"]):
        final_details.update(scrape_mmadecisions_details(mmadecisions_url))

    return final_details

# %%
# Main function to parse all fighters
def parse_all_fighters(fighter_names):
    all_fighters_details = []

    for fighter_name in tqdm_notebook(fighter_names, desc="Processing fighters"):
        details = aggregate_fighter_details(fighter_name)
        all_fighters_details.append(details)

    # Format output rows
    formatted_fighters_details = []
    for fighter in all_fighters_details:
        formatted_row = (
            f"{fighter.get('FIGHTER', '')},"
            f"{fighter.get('HEIGHT', '')},"
            f"{fighter.get('WEIGHT', '')},"
            f"{fighter.get('REACH', '')},"
            f"{fighter.get('STANCE', '')},"
            f"{fighter.get('DOB', '')},"
            f"{fighter.get('UFC_URL', '')},"
            f"{fighter.get('TAPOLOGY_URL', '')},"
            f"{fighter.get('MMADECISIONS_URL', '')}"
        )
        formatted_fighters_details.append(formatted_row)

    return formatted_fighters_details

# %%
# Example usage
if __name__ == "__main__":
    # Example list of fighter names
    fighter_names = pd.read_csv("data/fighter_names.csv")["Name"].tolist()

    # Parse all fighter details
    all_fighter_details = parse_all_fighters(fighter_names)

    # Save results to CSV format
    with open("all_fighter_details.csv", "w") as f:
        f.write("FIGHTER,HEIGHT,WEIGHT,REACH,STANCE,DOB,UFC_URL,TAPOLOGY_URL,MMADECISIONS_URL\n")
        for row in all_fighter_details:
            f.write(row + "\n")

    logging.info("Scraping complete. Data saved to all_fighter_details.csv.")
# Out:
# Processing fighters:   0%|          | 0/347 [00:00<?, ?it/s]
# 2025-01-26 23:12:07,942 - INFO - Found UFC Stats URL for Danny Abbadi: http://ufcstats.com/fighter-details/15df64c02b6b0fde
# 2025-01-26 23:12:08,674 - WARNING - Some details missing for UFC Stats: http://ufcstats.com/fighter-details/15df64c02b6b0fde
# 2025-01-26 23:12:09,797 - WARNING - Could not find Tapology URL for Danny Abbadi
# 2025-01-26 23:12:19,992 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Danny+Abbadi after 3 retries
# 2025-01-26 23:12:19,992 - WARNING - Failed to fetch MMA Decisions search results for Danny Abbadi
# 2025-01-26 23:12:21,228 - INFO - Found UFC Stats URL for David Abbott: http://ufcstats.com/fighter-details/b361180739bed4b0
# 2025-01-26 23:12:22,042 - WARNING - Some details missing for UFC Stats: http://ufcstats.com/fighter-details/b361180739bed4b0
# 2025-01-26 23:12:23,145 - WARNING - Could not find Tapology URL for David Abbott
# 2025-01-26 23:12:33,344 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=David+Abbott after 3 retries
# 2025-01-26 23:12:33,345 - WARNING - Failed to fetch MMA Decisions search results for David Abbott
# 2025-01-26 23:12:34,462 - INFO - Found UFC Stats URL for Papy Abedi: http://ufcstats.com/fighter-details/c0ed7b208197e8de
# 2025-01-26 23:12:35,156 - WARNING - Some details missing for UFC Stats: http://ufcstats.com/fighter-details/c0ed7b208197e8de
# 2025-01-26 23:12:36,312 - WARNING - Could not find Tapology URL for Papy Abedi
# 2025-01-26 23:12:46,496 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Papy+Abedi after 3 retries
# 2025-01-26 23:12:46,496 - WARNING - Failed to fetch MMA Decisions search results for Papy Abedi
# 2025-01-26 23:12:47,657 - INFO - Found UFC Stats URL for Ricardo Abreu: http://ufcstats.com/fighter-details/aa6e591c2a2cdecd
# 2025-01-26 23:12:48,376 - WARNING - Some details missing for UFC Stats: http://ufcstats.com/fighter-details/aa6e591c2a2cdecd
# 2025-01-26 23:12:49,517 - WARNING - Could not find Tapology URL for Ricardo Abreu
# 2025-01-26 23:12:59,807 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Ricardo+Abreu after 3 retries
# 2025-01-26 23:12:59,809 - WARNING - Failed to fetch MMA Decisions search results for Ricardo Abreu
# 2025-01-26 23:13:00,870 - INFO - Found UFC Stats URL for Scott Adams: http://ufcstats.com/fighter-details/2620f3eb21c79614
# 2025-01-26 23:13:01,671 - WARNING - Some details missing for UFC Stats: http://ufcstats.com/fighter-details/2620f3eb21c79614
# 2025-01-26 23:13:02,829 - WARNING - Could not find Tapology URL for Scott Adams
# 2025-01-26 23:13:13,096 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Scott+Adams after 3 retries
# 2025-01-26 23:13:13,096 - WARNING - Failed to fetch MMA Decisions search results for Scott Adams
# 2025-01-26 23:13:14,533 - INFO - Found UFC Stats URL for Sam Adkins: http://ufcstats.com/fighter-details/0e9869d712e81f8f
# 2025-01-26 23:13:15,242 - WARNING - Some details missing for UFC Stats: http://ufcstats.com/fighter-details/0e9869d712e81f8f
# 2025-01-26 23:13:16,403 - WARNING - Could not find Tapology URL for Sam Adkins
# 2025-01-26 23:13:26,626 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Sam+Adkins after 3 retries
# 2025-01-26 23:13:26,627 - WARNING - Failed to fetch MMA Decisions search results for Sam Adkins
# 2025-01-26 23:13:27,835 - INFO - Found UFC Stats URL for Nick Agallar: http://ufcstats.com/fighter-details/ebc5af72ad5a28cb
# 2025-01-26 23:13:28,529 - WARNING - Some details missing for UFC Stats: http://ufcstats.com/fighter-details/ebc5af72ad5a28cb
# 2025-01-26 23:13:29,666 - WARNING - Could not find Tapology URL for Nick Agallar
# 2025-01-26 23:13:39,852 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Nick+Agallar after 3 retries
# 2025-01-26 23:13:39,853 - WARNING - Failed to fetch MMA Decisions search results for Nick Agallar
# 2025-01-26 23:13:41,304 - INFO - Found UFC Stats URL for Marcelo Aguiar: http://ufcstats.com/fighter-details/44aa652b181bcf68
# 2025-01-26 23:13:42,611 - WARNING - Some details missing for UFC Stats: http://ufcstats.com/fighter-details/44aa652b181bcf68
# 2025-01-26 23:13:43,767 - WARNING - Could not find Tapology URL for Marcelo Aguiar
# 2025-01-26 23:13:54,026 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Marcelo+Aguiar after 3 retries
# 2025-01-26 23:13:54,027 - WARNING - Failed to fetch MMA Decisions search results for Marcelo Aguiar
# 2025-01-26 23:13:55,786 - INFO - Found UFC Stats URL for Razak Al-Hassan: http://ufcstats.com/fighter-details/38b50fd1e1b5b656
# 2025-01-26 23:13:57,408 - WARNING - Some details missing for UFC Stats: http://ufcstats.com/fighter-details/38b50fd1e1b5b656
# 2025-01-26 23:13:58,545 - WARNING - Could not find Tapology URL for Razak Al-Hassan
# 2025-01-26 23:14:08,891 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Razak+Al-Hassan after 3 retries
# 2025-01-26 23:14:08,892 - WARNING - Failed to fetch MMA Decisions search results for Razak Al-Hassan
# 2025-01-26 23:14:11,600 - INFO - Found UFC Stats URL for Wes Albritton: http://ufcstats.com/fighter-details/184b955181bdef52
# 2025-01-26 23:14:13,678 - WARNING - Some details missing for UFC Stats: http://ufcstats.com/fighter-details/184b955181bdef52
# 2025-01-26 23:14:14,798 - WARNING - Could not find Tapology URL for Wes Albritton
# 2025-01-26 23:14:25,021 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Wes+Albritton after 3 retries
# 2025-01-26 23:14:25,021 - WARNING - Failed to fetch MMA Decisions search results for Wes Albritton
# 2025-01-26 23:14:27,416 - INFO - Found UFC Stats URL for Alfonso Alcarez: http://ufcstats.com/fighter-details/1e38bba6738b7b10
# 2025-01-26 23:14:28,732 - WARNING - Some details missing for UFC Stats: http://ufcstats.com/fighter-details/1e38bba6738b7b10
# 2025-01-26 23:14:29,868 - WARNING - Could not find Tapology URL for Alfonso Alcarez
# 2025-01-26 23:14:40,042 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Alfonso+Alcarez after 3 retries
# 2025-01-26 23:14:40,042 - WARNING - Failed to fetch MMA Decisions search results for Alfonso Alcarez
# 2025-01-26 23:14:42,075 - INFO - Found UFC Stats URL for Gilbert Aldana: http://ufcstats.com/fighter-details/d26934530dc5b248
# 2025-01-26 23:14:43,207 - WARNING - Some details missing for UFC Stats: http://ufcstats.com/fighter-details/d26934530dc5b248
# 2025-01-26 23:14:44,394 - WARNING - Could not find Tapology URL for Gilbert Aldana
# 2025-01-26 23:14:54,562 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Gilbert+Aldana after 3 retries
# 2025-01-26 23:14:54,563 - WARNING - Failed to fetch MMA Decisions search results for Gilbert Aldana
# 2025-01-26 23:14:56,310 - INFO - Found UFC Stats URL for Royce Alger: http://ufcstats.com/fighter-details/669a3cb6e394f515
# 2025-01-26 23:14:57,341 - WARNING - Some details missing for UFC Stats: http://ufcstats.com/fighter-details/669a3cb6e394f515
# 2025-01-26 23:14:58,529 - WARNING - Could not find Tapology URL for Royce Alger
# 2025-01-26 23:15:08,745 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Royce+Alger after 3 retries
# 2025-01-26 23:15:08,745 - WARNING - Failed to fetch MMA Decisions search results for Royce Alger
# 2025-01-26 23:15:10,213 - INFO - Found UFC Stats URL for George Allen: http://ufcstats.com/fighter-details/1e13936d708bcff7
# 2025-01-26 23:15:12,065 - WARNING - Some details missing for UFC Stats: http://ufcstats.com/fighter-details/1e13936d708bcff7
# 2025-01-26 23:15:13,188 - WARNING - Could not find Tapology URL for George Allen
# 2025-01-26 23:15:23,414 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=George+Allen after 3 retries
# 2025-01-26 23:15:23,414 - WARNING - Failed to fetch MMA Decisions search results for George Allen
# 2025-01-26 23:15:24,784 - INFO - Found UFC Stats URL for Ericka Almeida: http://ufcstats.com/fighter-details/91186547a7f3f758
# 2025-01-26 23:15:25,683 - WARNING - Some details missing for UFC Stats: http://ufcstats.com/fighter-details/91186547a7f3f758
# 2025-01-26 23:15:26,832 - WARNING - Could not find Tapology URL for Ericka Almeida
# 2025-01-26 23:15:37,078 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Ericka+Almeida after 3 retries
# 2025-01-26 23:15:37,078 - WARNING - Failed to fetch MMA Decisions search results for Ericka Almeida
# 2025-01-26 23:15:38,991 - INFO - Found UFC Stats URL for Sean Alvarez: http://ufcstats.com/fighter-details/e741536153227386
# 2025-01-26 23:15:40,417 - WARNING - Some details missing for UFC Stats: http://ufcstats.com/fighter-details/e741536153227386
# 2025-01-26 23:15:41,589 - WARNING - Could not find Tapology URL for Sean Alvarez
# 2025-01-26 23:15:51,869 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Sean+Alvarez after 3 retries
# 2025-01-26 23:15:51,869 - WARNING - Failed to fetch MMA Decisions search results for Sean Alvarez
# 2025-01-26 23:15:53,347 - INFO - Found UFC Stats URL for Amilcar Alves: http://ufcstats.com/fighter-details/31ee470ef5dc8d7f
# 2025-01-26 23:15:54,745 - WARNING - Some details missing for UFC Stats: http://ufcstats.com/fighter-details/31ee470ef5dc8d7f
# 2025-01-26 23:15:55,913 - WARNING - Could not find Tapology URL for Amilcar Alves
# 2025-01-26 23:16:06,169 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Amilcar+Alves after 3 retries
# 2025-01-26 23:16:06,170 - WARNING - Failed to fetch MMA Decisions search results for Amilcar Alves
# 2025-01-26 23:16:08,292 - INFO - Found UFC Stats URL for Matt Andersen: http://ufcstats.com/fighter-details/cad24459b28592ca
# 2025-01-26 23:16:09,452 - WARNING - Some details missing for UFC Stats: http://ufcstats.com/fighter-details/cad24459b28592ca
# 2025-01-26 23:16:10,572 - WARNING - Could not find Tapology URL for Matt Andersen
# 2025-01-26 23:16:20,825 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Matt+Andersen after 3 retries
# 2025-01-26 23:16:20,826 - WARNING - Failed to fetch MMA Decisions search results for Matt Andersen
# 2025-01-26 23:16:22,342 - INFO - Found UFC Stats URL for Andy Anderson: http://ufcstats.com/fighter-details/cad24459b28592ca
# 2025-01-26 23:16:23,692 - WARNING - Some details missing for UFC Stats: http://ufcstats.com/fighter-details/cad24459b28592ca
# 2025-01-26 23:16:24,881 - WARNING - Could not find Tapology URL for Andy Anderson
# 2025-01-26 23:16:35,175 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Andy+Anderson after 3 retries
# 2025-01-26 23:16:35,175 - WARNING - Failed to fetch MMA Decisions search results for Andy Anderson
# 2025-01-26 23:16:36,304 - INFO - Found UFC Stats URL for Lowell Anderson: http://ufcstats.com/fighter-details/cad24459b28592ca
# 2025-01-26 23:16:37,307 - WARNING - Some details missing for UFC Stats: http://ufcstats.com/fighter-details/cad24459b28592ca
# 2025-01-26 23:16:38,445 - WARNING - Could not find Tapology URL for Lowell Anderson
# 2025-01-26 23:16:48,706 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Lowell+Anderson after 3 retries
# 2025-01-26 23:16:48,707 - WARNING - Failed to fetch MMA Decisions search results for Lowell Anderson
# 2025-01-26 23:16:50,741 - INFO - Found UFC Stats URL for Alex Andrade: http://ufcstats.com/fighter-details/1562b12763cc8d67
# 2025-01-26 23:16:51,678 - WARNING - Some details missing for UFC Stats: http://ufcstats.com/fighter-details/1562b12763cc8d67
# 2025-01-26 23:16:52,810 - WARNING - Could not find Tapology URL for Alex Andrade
# 2025-01-26 23:17:03,086 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Alex+Andrade after 3 retries
# 2025-01-26 23:17:03,087 - WARNING - Failed to fetch MMA Decisions search results for Alex Andrade
# 2025-01-26 23:17:04,465 - INFO - Found UFC Stats URL for Jermaine Andre: http://ufcstats.com/fighter-details/20821819c401ced8
# 2025-01-26 23:17:05,419 - WARNING - Some details missing for UFC Stats: http://ufcstats.com/fighter-details/20821819c401ced8
# 2025-01-26 23:17:06,642 - WARNING - Could not find Tapology URL for Jermaine Andre
# 2025-01-26 23:17:16,882 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Jermaine+Andre after 3 retries
# 2025-01-26 23:17:16,883 - WARNING - Failed to fetch MMA Decisions search results for Jermaine Andre
# 2025-01-26 23:17:18,333 - INFO - Found UFC Stats URL for Reese Andy: http://ufcstats.com/fighter-details/9199e0735b83dd32
# 2025-01-26 23:17:19,504 - WARNING - Some details missing for UFC Stats: http://ufcstats.com/fighter-details/9199e0735b83dd32
# 2025-01-26 23:17:20,661 - WARNING - Could not find Tapology URL for Reese Andy
# 2025-01-26 23:17:30,912 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Reese+Andy after 3 retries
# 2025-01-26 23:17:30,913 - WARNING - Failed to fetch MMA Decisions search results for Reese Andy
# 2025-01-26 23:17:32,023 - INFO - Found UFC Stats URL for Yoji Anjo: http://ufcstats.com/fighter-details/e06fd1260ac865a7
# 2025-01-26 23:17:32,738 - WARNING - Some details missing for UFC Stats: http://ufcstats.com/fighter-details/e06fd1260ac865a7
# 2025-01-26 23:17:33,907 - WARNING - Could not find Tapology URL for Yoji Anjo
# 2025-01-26 23:17:44,167 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Yoji+Anjo after 3 retries
# 2025-01-26 23:17:44,168 - WARNING - Failed to fetch MMA Decisions search results for Yoji Anjo
# 2025-01-26 23:17:45,400 - INFO - Found UFC Stats URL for Azunna Anyanwu: http://ufcstats.com/fighter-details/78d48d3874dacafd
# 2025-01-26 23:17:46,309 - WARNING - Some details missing for UFC Stats: http://ufcstats.com/fighter-details/78d48d3874dacafd
# 2025-01-26 23:17:47,461 - WARNING - Could not find Tapology URL for Azunna Anyanwu
# 2025-01-26 23:17:57,746 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Azunna+Anyanwu after 3 retries
# 2025-01-26 23:17:57,747 - WARNING - Failed to fetch MMA Decisions search results for Azunna Anyanwu
# 2025-01-26 23:17:59,195 - INFO - Found UFC Stats URL for Romie Aram: http://ufcstats.com/fighter-details/73ef22f25d0f70e2
# 2025-01-26 23:17:59,919 - WARNING - Some details missing for UFC Stats: http://ufcstats.com/fighter-details/73ef22f25d0f70e2
# 2025-01-26 23:18:01,096 - WARNING - Could not find Tapology URL for Romie Aram
# 2025-01-26 23:18:11,306 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Romie+Aram after 3 retries
# 2025-01-26 23:18:11,307 - WARNING - Failed to fetch MMA Decisions search results for Romie Aram
# 2025-01-26 23:18:12,489 - INFO - Found UFC Stats URL for Cesar Arzamendia: http://ufcstats.com/fighter-details/64d47ef881a437a4
# 2025-01-26 23:18:13,213 - WARNING - Some details missing for UFC Stats: http://ufcstats.com/fighter-details/64d47ef881a437a4
# 2025-01-26 23:18:14,330 - WARNING - Could not find Tapology URL for Cesar Arzamendia
# 2025-01-26 23:18:24,509 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Cesar+Arzamendia after 3 retries
# 2025-01-26 23:18:24,511 - WARNING - Failed to fetch MMA Decisions search results for Cesar Arzamendia
# 2025-01-26 23:18:25,643 - INFO - Found UFC Stats URL for Khusein Askhabov: http://ufcstats.com/fighter-details/5c10da56d712ac9c
# 2025-01-26 23:18:26,352 - WARNING - Some details missing for UFC Stats: http://ufcstats.com/fighter-details/5c10da56d712ac9c
# 2025-01-26 23:18:27,488 - WARNING - Could not find Tapology URL for Khusein Askhabov
# 2025-01-26 23:18:37,685 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Khusein+Askhabov after 3 retries
# 2025-01-26 23:18:37,686 - WARNING - Failed to fetch MMA Decisions search results for Khusein Askhabov
# 2025-01-26 23:18:38,716 - INFO - Found UFC Stats URL for Ibo Aslan: http://ufcstats.com/fighter-details/6e8f1bcdda94ff45
# 2025-01-26 23:18:39,429 - WARNING - Some details missing for UFC Stats: http://ufcstats.com/fighter-details/6e8f1bcdda94ff45
# 2025-01-26 23:18:40,608 - WARNING - Could not find Tapology URL for Ibo Aslan
# 2025-01-26 23:18:50,931 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Ibo+Aslan after 3 retries
# 2025-01-26 23:18:50,932 - WARNING - Failed to fetch MMA Decisions search results for Ibo Aslan
# 2025-01-26 23:18:52,185 - INFO - Found UFC Stats URL for Pat Audinwood: http://ufcstats.com/fighter-details/196ed28337adc630
# 2025-01-26 23:18:52,861 - WARNING - Some details missing for UFC Stats: http://ufcstats.com/fighter-details/196ed28337adc630
# 2025-01-26 23:18:53,999 - WARNING - Could not find Tapology URL for Pat Audinwood
# 2025-01-26 23:19:04,235 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Pat+Audinwood after 3 retries
# 2025-01-26 23:19:04,236 - WARNING - Failed to fetch MMA Decisions search results for Pat Audinwood
# 2025-01-26 23:19:05,552 - INFO - Found UFC Stats URL for Chris Avila: http://ufcstats.com/fighter-details/ee0b69e307c857e5
# 2025-01-26 23:19:06,225 - WARNING - Some details missing for UFC Stats: http://ufcstats.com/fighter-details/ee0b69e307c857e5
# 2025-01-26 23:19:07,362 - WARNING - Could not find Tapology URL for Chris Avila
# 2025-01-26 23:19:17,562 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Chris+Avila after 3 retries
# 2025-01-26 23:19:17,563 - WARNING - Failed to fetch MMA Decisions search results for Chris Avila
# 2025-01-26 23:19:18,716 - WARNING - Could not find UFC Stats URL for Niklas Backstrom
# 2025-01-26 23:19:19,881 - WARNING - Could not find Tapology URL for Niklas Backstrom
# 2025-01-26 23:19:30,076 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Niklas+Backstrom after 3 retries
# 2025-01-26 23:19:30,077 - WARNING - Failed to fetch MMA Decisions search results for Niklas Backstrom
# 2025-01-26 23:19:31,155 - INFO - Found UFC Stats URL for Izabela Badurek: http://ufcstats.com/fighter-details/c0ed7b208197e8de
# 2025-01-26 23:19:31,900 - WARNING - Some details missing for UFC Stats: http://ufcstats.com/fighter-details/c0ed7b208197e8de
# 2025-01-26 23:19:33,030 - WARNING - Could not find Tapology URL for Izabela Badurek
# 2025-01-26 23:19:43,197 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Izabela+Badurek after 3 retries
# 2025-01-26 23:19:43,199 - WARNING - Failed to fetch MMA Decisions search results for Izabela Badurek
# 2025-01-26 23:19:44,438 - WARNING - Could not find UFC Stats URL for Mehdi Baghdad
# 2025-01-26 23:19:45,636 - WARNING - Could not find Tapology URL for Mehdi Baghdad
# 2025-01-26 23:19:55,803 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Mehdi+Baghdad after 3 retries
# 2025-01-26 23:19:55,804 - WARNING - Failed to fetch MMA Decisions search results for Mehdi Baghdad
# 2025-01-26 23:19:57,002 - INFO - Found UFC Stats URL for Scott Baker: http://ufcstats.com/fighter-details/2620f3eb21c79614
# 2025-01-26 23:19:57,711 - WARNING - Some details missing for UFC Stats: http://ufcstats.com/fighter-details/2620f3eb21c79614
# 2025-01-26 23:19:58,838 - WARNING - Could not find Tapology URL for Scott Baker
# 2025-01-26 23:20:09,054 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Scott+Baker after 3 retries
# 2025-01-26 23:20:09,054 - WARNING - Failed to fetch MMA Decisions search results for Scott Baker
# 2025-01-26 23:20:10,400 - INFO - Found UFC Stats URL for Marcin Bandel: http://ufcstats.com/fighter-details/d53482bef23235ba
# 2025-01-26 23:20:11,228 - WARNING - Some details missing for UFC Stats: http://ufcstats.com/fighter-details/d53482bef23235ba
# 2025-01-26 23:20:12,377 - WARNING - Could not find Tapology URL for Marcin Bandel
# 2025-01-26 23:20:22,661 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Marcin+Bandel after 3 retries
# 2025-01-26 23:20:22,663 - WARNING - Failed to fetch MMA Decisions search results for Marcin Bandel
# 2025-01-26 23:20:23,785 - INFO - Found UFC Stats URL for David Baron: http://ufcstats.com/fighter-details/b361180739bed4b0
# 2025-01-26 23:20:24,645 - WARNING - Some details missing for UFC Stats: http://ufcstats.com/fighter-details/b361180739bed4b0
# 2025-01-26 23:20:25,783 - WARNING - Could not find Tapology URL for David Baron
# 2025-01-26 23:20:35,997 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=David+Baron after 3 retries
# 2025-01-26 23:20:35,998 - WARNING - Failed to fetch MMA Decisions search results for David Baron
# 2025-01-26 23:20:37,162 - INFO - Found UFC Stats URL for Dan Barrera: http://ufcstats.com/fighter-details/e4ba58725825412d
# 2025-01-27 03:00:17,507 - WARNING - Some details missing for UFC Stats: http://ufcstats.com/fighter-details/e4ba58725825412d
# 2025-01-27 03:00:17,537 - WARNING - Retrying (1/3) for https://www.tapology.com/search/mma-fighters/Dan%20Barrera: HTTPSConnectionPool(host='www.tapology.com', port=443): Max retries exceeded with url: /search/mma-fighters/Dan%20Barrera (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020D7BCF8A10>: Failed to resolve 'www.tapology.com' ([Errno 11001] getaddrinfo failed)"))
# 2025-01-27 06:51:05,339 - WARNING - Could not find Tapology URL for Dan Barrera
# 2025-01-27 07:49:44,062 - WARNING - Retrying (3/3) for https://mmadecisions.com/search.php?search_query=Dan+Barrera: HTTPSConnectionPool(host='mmadecisions.com', port=443): Max retries exceeded with url: /search.php?search_query=Dan+Barrera (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020D7CE913A0>: Failed to resolve 'mmadecisions.com' ([Errno 11001] getaddrinfo failed)"))
# 2025-01-27 07:49:48,065 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Dan+Barrera after 3 retries
# 2025-01-27 07:49:48,066 - WARNING - Failed to fetch MMA Decisions search results for Dan Barrera
# 2025-01-27 07:49:48,073 - WARNING - Retrying (1/3) for http://ufcstats.com/statistics/fighters?char=a&page=all: HTTPConnectionPool(host='ufcstats.com', port=80): Max retries exceeded with url: /statistics/fighters?char=a&page=all (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x0000020D7C455DF0>: Failed to resolve 'ufcstats.com' ([Errno 11001] getaddrinfo failed)"))
# 2025-01-27 07:49:49,078 - WARNING - Retrying (2/3) for http://ufcstats.com/statistics/fighters?char=a&page=all: HTTPConnectionPool(host='ufcstats.com', port=80): Max retries exceeded with url: /statistics/fighters?char=a&page=all (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x0000020D7C456600>: Failed to resolve 'ufcstats.com' ([Errno 11001] getaddrinfo failed)"))
# 2025-01-27 08:24:35,343 - WARNING - Retrying (3/3) for http://ufcstats.com/statistics/fighters?char=a&page=all: HTTPConnectionPool(host='ufcstats.com', port=80): Max retries exceeded with url: /statistics/fighters?char=a&page=all (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x0000020D7C456E40>: Failed to resolve 'ufcstats.com' ([Errno 11001] getaddrinfo failed)"))
# 2025-01-27 08:24:39,348 - ERROR - Failed to fetch http://ufcstats.com/statistics/fighters?char=a&page=all after 3 retries
# 2025-01-27 08:24:39,349 - WARNING - Failed to fetch UFC Stats directory for Carlos Barreto
# 2025-01-27 08:24:39,354 - WARNING - Retrying (1/3) for https://www.tapology.com/search/mma-fighters/Carlos%20Barreto: HTTPSConnectionPool(host='www.tapology.com', port=443): Max retries exceeded with url: /search/mma-fighters/Carlos%20Barreto (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020D7C457740>: Failed to resolve 'www.tapology.com' ([Errno 11001] getaddrinfo failed)"))
# 2025-01-27 08:24:40,357 - WARNING - Retrying (2/3) for https://www.tapology.com/search/mma-fighters/Carlos%20Barreto: HTTPSConnectionPool(host='www.tapology.com', port=443): Max retries exceeded with url: /search/mma-fighters/Carlos%20Barreto (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020D7CE90CB0>: Failed to resolve 'www.tapology.com' ([Errno 11001] getaddrinfo failed)"))
# 2025-01-27 08:24:42,364 - WARNING - Retrying (3/3) for https://www.tapology.com/search/mma-fighters/Carlos%20Barreto: HTTPSConnectionPool(host='www.tapology.com', port=443): Max retries exceeded with url: /search/mma-fighters/Carlos%20Barreto (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020D7C456A20>: Failed to resolve 'www.tapology.com' ([Errno 11001] getaddrinfo failed)"))
# 2025-01-27 08:24:46,367 - ERROR - Failed to fetch https://www.tapology.com/search/mma-fighters/Carlos%20Barreto after 3 retries
# 2025-01-27 08:24:46,368 - WARNING - Failed to fetch Tapology search results for Carlos Barreto
# 2025-01-27 08:24:46,370 - WARNING - Retrying (1/3) for https://mmadecisions.com/search.php?search_query=Carlos+Barreto: HTTPSConnectionPool(host='mmadecisions.com', port=443): Max retries exceeded with url: /search.php?search_query=Carlos+Barreto (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020D7C4560F0>: Failed to resolve 'mmadecisions.com' ([Errno 11001] getaddrinfo failed)"))
# 2025-01-27 08:24:47,378 - WARNING - Retrying (2/3) for https://mmadecisions.com/search.php?search_query=Carlos+Barreto: HTTPSConnectionPool(host='mmadecisions.com', port=443): Max retries exceeded with url: /search.php?search_query=Carlos+Barreto (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020D7C455580>: Failed to resolve 'mmadecisions.com' ([Errno 11001] getaddrinfo failed)"))
# 2025-01-27 08:24:49,381 - WARNING - Retrying (3/3) for https://mmadecisions.com/search.php?search_query=Carlos+Barreto: HTTPSConnectionPool(host='mmadecisions.com', port=443): Max retries exceeded with url: /search.php?search_query=Carlos+Barreto (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020D7C457830>: Failed to resolve 'mmadecisions.com' ([Errno 11001] getaddrinfo failed)"))
# 2025-01-27 08:24:53,386 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Carlos+Barreto after 3 retries
# 2025-01-27 08:24:53,386 - WARNING - Failed to fetch MMA Decisions search results for Carlos Barreto
# 2025-01-27 08:24:55,782 - INFO - Found UFC Stats URL for Alexandre Barros: http://ufcstats.com/fighter-details/20821819c401ced8
# 2025-01-27 08:24:56,475 - WARNING - Some details missing for UFC Stats: http://ufcstats.com/fighter-details/20821819c401ced8
# 2025-01-27 08:24:58,021 - WARNING - Could not find Tapology URL for Alexandre Barros
# 2025-01-27 08:25:08,741 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Alexandre+Barros after 3 retries
# 2025-01-27 08:25:08,741 - WARNING - Failed to fetch MMA Decisions search results for Alexandre Barros
# 2025-01-27 08:25:10,087 - WARNING - Could not find UFC Stats URL for Dean Barry
# 2025-01-27 08:25:11,166 - WARNING - Could not find Tapology URL for Dean Barry
# 2025-01-27 08:25:21,276 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Dean+Barry after 3 retries
# 2025-01-27 08:25:21,278 - WARNING - Failed to fetch MMA Decisions search results for Dean Barry
# 2025-01-27 08:25:22,471 - WARNING - Could not find UFC Stats URL for Stephen Bass
# 2025-01-27 08:25:23,700 - WARNING - Could not find Tapology URL for Stephen Bass
# 2025-01-27 08:25:33,807 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Stephen+Bass after 3 retries
# 2025-01-27 08:25:33,809 - WARNING - Failed to fetch MMA Decisions search results for Stephen Bass
# 2025-01-27 08:25:35,128 - WARNING - Could not find UFC Stats URL for Shayna Baszler
# 2025-01-27 08:25:36,174 - WARNING - Could not find Tapology URL for Shayna Baszler
# 2025-01-27 08:25:46,101 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Shayna+Baszler after 3 retries
# 2025-01-27 08:25:46,101 - WARNING - Failed to fetch MMA Decisions search results for Shayna Baszler
# 2025-01-27 08:25:47,389 - INFO - Found UFC Stats URL for Michel Batista: http://ufcstats.com/fighter-details/01c9e4013afce141
# 2025-01-27 08:25:48,053 - WARNING - Some details missing for UFC Stats: http://ufcstats.com/fighter-details/01c9e4013afce141
# 2025-01-27 08:25:49,124 - WARNING - Could not find Tapology URL for Michel Batista
# 2025-01-27 08:25:59,056 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Michel+Batista after 3 retries
# 2025-01-27 08:25:59,056 - WARNING - Failed to fetch MMA Decisions search results for Michel Batista
# 2025-01-27 08:26:00,650 - INFO - Found UFC Stats URL for Dave Beneteau: http://ufcstats.com/fighter-details/c4fe2e9a06ea5bcb
# 2025-01-27 08:26:01,389 - WARNING - Some details missing for UFC Stats: http://ufcstats.com/fighter-details/c4fe2e9a06ea5bcb
# 2025-01-27 08:26:02,488 - WARNING - Could not find Tapology URL for Dave Beneteau
# 2025-01-27 08:26:12,462 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Dave+Beneteau after 3 retries
# 2025-01-27 08:26:12,464 - WARNING - Failed to fetch MMA Decisions search results for Dave Beneteau
# 2025-01-27 08:26:13,787 - WARNING - Could not find UFC Stats URL for Steve Berger
# 2025-01-27 08:26:14,889 - WARNING - Could not find Tapology URL for Steve Berger
# 2025-01-27 08:26:24,826 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Steve+Berger after 3 retries
# 2025-01-27 08:26:24,828 - WARNING - Failed to fetch MMA Decisions search results for Steve Berger
# 2025-01-27 08:26:26,224 - WARNING - Could not find UFC Stats URL for Keith Berish
# 2025-01-27 08:26:27,474 - WARNING - Could not find Tapology URL for Keith Berish
# 2025-01-27 08:26:37,544 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Keith+Berish after 3 retries
# 2025-01-27 08:26:37,544 - WARNING - Failed to fetch MMA Decisions search results for Keith Berish
# 2025-01-27 08:26:38,953 - WARNING - Could not find UFC Stats URL for Dave Berry
# 2025-01-27 08:26:40,026 - WARNING - Could not find Tapology URL for Dave Berry
# 2025-01-27 08:26:50,086 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Dave+Berry after 3 retries
# 2025-01-27 08:26:50,086 - WARNING - Failed to fetch MMA Decisions search results for Dave Berry
# 2025-01-27 08:26:51,487 - INFO - Found UFC Stats URL for Dieusel Berto: http://ufcstats.com/fighter-details/7bd94b60d7521e4a
# 2025-01-27 08:26:52,150 - WARNING - Some details missing for UFC Stats: http://ufcstats.com/fighter-details/7bd94b60d7521e4a
# 2025-01-27 08:26:53,191 - WARNING - Could not find Tapology URL for Dieusel Berto
# 2025-01-27 08:27:03,372 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Dieusel+Berto after 3 retries
# 2025-01-27 08:27:03,372 - WARNING - Failed to fetch MMA Decisions search results for Dieusel Berto
# 2025-01-27 08:27:05,006 - INFO - Found UFC Stats URL for Allen Berube: http://ufcstats.com/fighter-details/1e13936d708bcff7
# 2025-01-27 08:27:05,665 - WARNING - Some details missing for UFC Stats: http://ufcstats.com/fighter-details/1e13936d708bcff7
# 2025-01-27 08:27:06,773 - WARNING - Could not find Tapology URL for Allen Berube
# 2025-01-27 08:27:16,994 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Allen+Berube after 3 retries
# 2025-01-27 08:27:16,994 - WARNING - Failed to fetch MMA Decisions search results for Allen Berube
# 2025-01-27 08:27:18,158 - INFO - Found UFC Stats URL for Scott Bessac: http://ufcstats.com/fighter-details/2620f3eb21c79614
# 2025-01-27 08:27:18,815 - WARNING - Some details missing for UFC Stats: http://ufcstats.com/fighter-details/2620f3eb21c79614
# 2025-01-27 08:27:19,984 - WARNING - Could not find Tapology URL for Scott Bessac
# 2025-01-27 08:27:29,929 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Scott+Bessac after 3 retries
# 2025-01-27 08:27:29,929 - WARNING - Failed to fetch MMA Decisions search results for Scott Bessac
# 2025-01-27 08:27:31,354 - WARNING - Could not find UFC Stats URL for Amaury Bitetti
# 2025-01-27 08:27:32,422 - WARNING - Could not find Tapology URL for Amaury Bitetti
# 2025-01-27 08:27:42,423 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Amaury+Bitetti after 3 retries
# 2025-01-27 08:27:42,424 - WARNING - Failed to fetch MMA Decisions search results for Amaury Bitetti
# 2025-01-27 08:27:43,872 - WARNING - Could not find UFC Stats URL for Jason Black
# 2025-01-27 08:27:44,937 - WARNING - Could not find Tapology URL for Jason Black
# 2025-01-27 08:27:54,942 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Jason+Black after 3 retries
# 2025-01-27 08:27:54,943 - WARNING - Failed to fetch MMA Decisions search results for Jason Black
# 2025-01-27 08:27:56,395 - INFO - Found UFC Stats URL for Tom Blackledge: http://ufcstats.com/fighter-details/93fe7332d16c6ad9
# 2025-01-27 08:27:57,203 - WARNING - Some details missing for UFC Stats: http://ufcstats.com/fighter-details/93fe7332d16c6ad9
# 2025-01-27 08:27:58,473 - WARNING - Could not find Tapology URL for Tom Blackledge
# 2025-01-27 08:28:08,509 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Tom+Blackledge after 3 retries
# 2025-01-27 08:28:08,509 - WARNING - Failed to fetch MMA Decisions search results for Tom Blackledge
# 2025-01-27 08:28:10,129 - WARNING - Could not find UFC Stats URL for Byron Bloodworth
# 2025-01-27 08:28:11,203 - WARNING - Could not find Tapology URL for Byron Bloodworth
# 2025-01-27 08:28:21,124 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Byron+Bloodworth after 3 retries
# 2025-01-27 08:28:21,125 - WARNING - Failed to fetch MMA Decisions search results for Byron Bloodworth
# 2025-01-27 08:28:22,379 - INFO - Found UFC Stats URL for Dan Bobish: http://ufcstats.com/fighter-details/e4ba58725825412d
# 2025-01-27 08:28:23,116 - WARNING - Some details missing for UFC Stats: http://ufcstats.com/fighter-details/e4ba58725825412d
# 2025-01-27 08:28:24,320 - WARNING - Could not find Tapology URL for Dan Bobish
# 2025-01-27 08:28:34,306 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Dan+Bobish after 3 retries
# 2025-01-27 08:28:34,307 - WARNING - Failed to fetch MMA Decisions search results for Dan Bobish
# 2025-01-27 08:28:35,762 - INFO - Found UFC Stats URL for Jerry Bohlander: http://ufcstats.com/fighter-details/cad24459b28592ca
# 2025-01-27 08:28:36,706 - WARNING - Some details missing for UFC Stats: http://ufcstats.com/fighter-details/cad24459b28592ca
# 2025-01-27 08:28:37,777 - WARNING - Could not find Tapology URL for Jerry Bohlander
# 2025-01-27 08:28:47,743 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Jerry+Bohlander after 3 retries
# 2025-01-27 08:28:47,744 - WARNING - Failed to fetch MMA Decisions search results for Jerry Bohlander
# 2025-01-27 08:28:49,166 - WARNING - Could not find UFC Stats URL for Jesse Bongfeldt
# 2025-01-27 08:28:50,238 - WARNING - Could not find Tapology URL for Jesse Bongfeldt
# 2025-01-27 08:29:00,228 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Jesse+Bongfeldt after 3 retries
# 2025-01-27 08:29:00,230 - WARNING - Failed to fetch MMA Decisions search results for Jesse Bongfeldt
# 2025-01-27 08:29:01,690 - INFO - Found UFC Stats URL for Marcus Bossett: http://ufcstats.com/fighter-details/04643fd03d9159cc
# 2025-01-27 08:29:02,786 - WARNING - Some details missing for UFC Stats: http://ufcstats.com/fighter-details/04643fd03d9159cc
# 2025-01-27 08:29:03,912 - WARNING - Could not find Tapology URL for Marcus Bossett
# 2025-01-27 08:29:13,865 - ERROR - Failed to fetch https://mmadecisions.com/search.php?search_query=Marcus+Bossett after 3 retries
# 2025-01-27 08:29:13,865 - WARNING - Failed to fetch MMA Decisions search results for Marcus Bossett
# 2025-01-27 08:29:15,481 - WARNING - Could not find UFC Stats URL for Tai Bowden
# 2025-01-27 08:29:16,595 - WARNING - Could not find Tapology URL for Tai Bowden
